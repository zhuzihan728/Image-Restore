# %% [markdown]
# <a href="https://colab.research.google.com/github/zhuzihan728/Image-Restore/blob/main/image_gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
from PIL import Image
import random
import json

def listdir(path, list_name):
    list_dirs = os.listdir(path)
    list_dirs.sort()
    for file in list_dirs:
        file_path = os.path.join(path, file)
        if os.path.isdir(file_path):
            listdir(file_path, list_name)
        else:
            list_name.append(file_path)
    list_name.sort()


class ImageFolderPreprocess:
    def __init__(self, root, root_bg, output_dir, alpha_ranges=[(0.1, 0.5), (0.5, 0.8), (0.8, 1.0)]):
        """
        :param root: path to original images
        :param root_bg: path to background/mask images
        :param output_dir: where to save preprocessed images
        :param mask_scale_range: (min, max) scale factor for mask relative to image size
        """
        self.img_root = root
        self.bg_root = root_bg
        self.output_dir = output_dir
        self.frame, self.bg_frame = self._parse_frame()
        print(f"Total images: {len(self.frame)}")
        print(f"Total background images: {len(self.bg_frame)}")
        self.metadata = []

        self.alpha_ranges = alpha_ranges
        os.makedirs(os.path.join(output_dir, 'corrupted'), exist_ok=True)

    def _parse_frame(self):
        img_names = []
        bg_names = []

        for fname in os.listdir(self.img_root):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_names.append(fname)

        for fname in os.listdir(self.bg_root):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                bg_names.append(fname)

        img_names.sort()
        bg_names.sort()

        random.shuffle(img_names)
        random.shuffle(bg_names)

        return img_names, bg_names

    def __len__(self):
        return len(self.frame)


    def create_mask(self, img_forbg, strength, w, h):
        img_forbg = img_forbg.resize((w, h), Image.Resampling.LANCZOS)
        alpha_channel = np.array(img_forbg).astype(np.float32)
        print(alpha_channel.max(), alpha_channel.min())
        alpha_channel = alpha_channel * strength + 255 * (1 - strength)
        alpha_channel = alpha_channel.astype(np.uint8)
        return alpha_channel


    def __getitem__(self, idx):
        img_name = self.frame[idx]
        file = os.path.join(self.img_root, img_name)
        img = Image.open(file).convert('RGB')

        mask_name = self.bg_frame[idx]
        file_bg = os.path.join(self.bg_root, mask_name)
        img_forbg = Image.open(file_bg).convert('L')

        # Apply blending at ORIGINAL size
        original_image_rgba = img.convert("RGBA")
        w, h = original_image_rgba.size
        for alpha_range in self.alpha_ranges:
            # Random strength for blending
            strength = random.uniform(alpha_range[0], alpha_range[1])
            strength = round(strength, 2)
            print(f"Strength: {strength}")

            # Apply blending
            alpha_channel = self.create_mask(img_forbg, strength, w, h)

            original_array_rgba = np.array(original_image_rgba)
            original_array_rgba[..., 3] = alpha_channel

            img_rgb = self.rgba_to_rgb(original_array_rgba)
            img_rgb = Image.fromarray(img_rgb)

            # Save only corrupted image
            print(f"Created corrupted image {idx}, alpha: {alpha_range}")
            save_name = f"{idx:05d}_alpha{str(alpha_range[0]).replace('.', '')}-{str(alpha_range[1]).replace('.', '')}.png"  # Fixed: string formatting
            img_rgb.save(os.path.join(self.output_dir, 'corrupted', save_name))

            # Store metadata with original and mask image names
            meta = {
                "id": idx,
                "corrupted_image": save_name,
                "original_image": img_name,
                "mask_image": mask_name,
                "alpha_range": alpha_range,
                "strength": float(strength),
                "image_size": [img.width, img.height],
                "mask_size": [img_forbg.width, img_forbg.height]
            }
            self.metadata.append(meta)

    def rgba_to_rgb(self, rgba_image):
        """Convert RGBA to RGB with white background"""
        rgb = np.zeros((rgba_image.shape[0], rgba_image.shape[1], 3), dtype=np.uint8)
        rgb[:, :] = 255  # White background

        alpha = rgba_image[:, :, 3:4] / 255.0
        rgb = (rgba_image[:, :, :3] * alpha + rgb * (1 - alpha)).astype(np.uint8)
        return rgb

    def save_metadata(self):
        """Save metadata to JSON file"""
        json_path = os.path.join(self.output_dir, 'metadata.json')
        with open(json_path, 'w') as f:
            json.dump(self.metadata, f, indent=2)
        print(f"Metadata saved to {json_path}")


# Usage:
# dataset = ImageFolderPreprocess(
#     root='images/',
#     root_bg='backgrounds/',
#     output_dir='eval_dataset/',
#     mask_scale_range=(1.0, 1.5)
# )

# for i in range(len(dataset)):
#     dataset[i]
#     if i % 100 == 0:
#         print(f"Processed {i}/{len(dataset)} images")

# dataset.save_metadata()

# %%
class EvalDataset:
    def __init__(self, corrupted_dir, original_dir, mask_dir, metadata_path,
                 im_size=None, transform=None):
        """
        :param corrupted_dir: path to corrupted images folder
        :param original_dir: path to original images folder
        :param mask_dir: path to mask images folder
        :param metadata_path: path to metadata.json
        :param im_size: target size (h, w) or None to keep original
        """
        self.corrupted_dir = corrupted_dir
        self.original_dir = original_dir
        self.mask_dir = mask_dir
        self.im_size = im_size
        self.transform = transform

        with open(metadata_path, 'r') as f:
            self.metadata = json.load(f)

    def __len__(self):
        return len(self.metadata)

    def __getitem__(self, idx):
        meta = self.metadata[idx]

        # Load images using names from metadata
        corrupted = Image.open(os.path.join(self.corrupted_dir, meta['corrupted_image']))
        original = Image.open(os.path.join(self.original_dir, meta['original_image']))

        # Resize if needed
        if self.im_size:
            corrupted = corrupted.resize(self.im_size, Image.Resampling.LANCZOS)
            original = original.resize(self.im_size, Image.Resampling.LANCZOS)

        if self.transform:
            corrupted = self.transform(corrupted)
            original = self.transform(original)

        return corrupted, original, meta

# Usage in evaluation:
# eval_dataset = EvalDataset(
#     corrupted_dir='eval_dataset/corrupted/',
#     original_dir='images/',  # Original folder
#     mask_dir='backgrounds/',  # Mask folder
#     metadata_path='eval_dataset/metadata.json',
#     im_size=(256, 256)
# )

# %%
all_mask_ls = []
listdir('/content/drive/MyDrive/Chris/data/mask', all_mask_ls)
print(f"Total masks: {len(all_mask_ls)}")
# Out:
# Total masks: 750

# %%
import shutil

all_images_ls = []
train_images_ls = []
test_images_ls = []

listdir('/content/drive/MyDrive/image/', all_images_ls)

print(f"Total images: {len(all_images_ls)}")
ratio = 1 - 100 / len(all_images_ls)
train_indices = random.sample(range(len(all_images_ls)), int(ratio * len(all_images_ls)))
test_indices = [i for i in range(len(all_images_ls)) if i not in train_indices]
print(f"Train images: {len(train_indices)}")
print(f"Test images: {len(test_indices)}")

assert len(train_indices) + len(test_indices) == len(all_images_ls)
# Out:
# Total images: 750
# Train images: 650
# Test images: 100

# %%
for i in train_indices:
    train_images_ls.append(all_images_ls[i])

for i in test_indices:
    test_images_ls.append(all_images_ls[i])

train_image_folder = '/content/drive/MyDrive/Chris/data/image_train'
test_image_folder = '/content/drive/MyDrive/Chris/data/image_test'
# save train and test images to two folders

if not os.path.exists(train_image_folder):
    os.makedirs(train_image_folder)

if not os.path.exists(test_image_folder):
    os.makedirs(test_image_folder)
for i in train_images_ls:
    shutil.copy(i, train_image_folder)

for i in test_images_ls:
    shutil.copy(i, test_image_folder)

# %%
from IPython.testing import test
train_copy_ls = []
test_copy_ls = []

listdir('/content/drive/MyDrive/Chris/data/image_train', train_copy_ls)
listdir('/content/drive/MyDrive/Chris/data/image_test', test_copy_ls)

all_image_file_name = [os.path.basename(i) for i in all_images_ls]
train_image_file_name = [os.path.basename(i) for i in train_copy_ls]
test_image_file_name = [os.path.basename(i) for i in test_copy_ls]
# verify train and test are exclusive, and are in all_images_ls
for i in train_image_file_name:
    assert i in all_image_file_name
    assert i not in test_image_file_name

for i in test_image_file_name:
    assert i in all_image_file_name
    assert i not in train_image_file_name

len(train_copy_ls), len(test_copy_ls)
# Out:
# (650, 100)

# %%
import shutil

all_masks_ls = []
train_masks_ls = []
test_masks_ls = []

listdir('/content/drive/MyDrive/Chris/data/mask', all_masks_ls)

print(f"Total masks: {len(all_masks_ls)}")
ratio = 1 - 100 / len(all_masks_ls)
train_indices = random.sample(range(len(all_masks_ls)), int(ratio * len(all_masks_ls)))
test_indices = [i for i in range(len(all_masks_ls)) if i not in train_indices]
print(f"Train images: {len(train_indices)}")
print(f"Test images: {len(test_indices)}")

assert len(train_indices) + len(test_indices) == len(all_masks_ls)
# Out:
# Total masks: 750
# Train images: 650
# Test images: 100

# %%
for i in train_indices:
    train_masks_ls.append(all_masks_ls[i])

for i in test_indices:
    test_masks_ls.append(all_masks_ls[i])

train_mask_folder = '/content/drive/MyDrive/Chris/data/mask_train'
test_mask_folder = '/content/drive/MyDrive/Chris/data/mask_test'

if not os.path.exists(train_mask_folder):
    os.makedirs(train_mask_folder)

if not os.path.exists(test_mask_folder):
    os.makedirs(test_mask_folder)
for i in train_masks_ls:
    shutil.copy(i, train_mask_folder)

for i in test_masks_ls:
    shutil.copy(i, test_mask_folder)

# %%
from IPython.testing import test
train_copy_ls = []
test_copy_ls = []

listdir('/content/drive/MyDrive/Chris/data/mask_train', train_copy_ls)
listdir('/content/drive/MyDrive/Chris/data/mask_test', test_copy_ls)

all_mask_file_name = [os.path.basename(i) for i in all_masks_ls]
train_mask_file_name = [os.path.basename(i) for i in train_copy_ls]
test_mask_file_name = [os.path.basename(i) for i in test_copy_ls]

for i in train_mask_file_name:
    assert i in all_mask_file_name
    assert i not in test_mask_file_name

for i in test_mask_file_name:
    assert i in all_mask_file_name
    assert i not in train_mask_file_name

len(train_copy_ls), len(test_copy_ls)
# Out:
# (650, 100)

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Save directly to Drive
dataset = ImageFolderPreprocess(
    root='/content/drive/MyDrive/Chris/data/image_train',
    root_bg='/content/drive/MyDrive/Chris/data/mask_train',
    output_dir='/content/drive/MyDrive/Chris/data/train_dataset/',  # Direct to Drive
    alpha_ranges=[(0.1, 0.5), (0.5, 0.8), (0.8, 1.0)]
)

# Process all images
for i in range(len(dataset)):
    dataset[i]

#     if i % 100 == 0:
#         print(f"Processed {i}/{len(dataset)} images")

# Save metadata
dataset.save_metadata()
print("✓ All files saved to Google Drive!")
# Out:
# Streaming output truncated to the last 5000 lines.
# Strength: 0.97
# 254.0 153.0
# Created corrupted image 94, alpha: (0.8, 1.0)
# Strength: 0.21
# 225.0 24.0
# Created corrupted image 95, alpha: (0.1, 0.5)
# Strength: 0.66
# 225.0 24.0
# Created corrupted image 95, alpha: (0.5, 0.8)
# Strength: 0.84
# 225.0 24.0
# Created corrupted image 95, alpha: (0.8, 1.0)
# Strength: 0.31
# 148.0 42.0
# Created corrupted image 96, alpha: (0.1, 0.5)
# Strength: 0.78
# 148.0 42.0
# Created corrupted image 96, alpha: (0.5, 0.8)
# Strength: 0.99
# 148.0 42.0
# Created corrupted image 96, alpha: (0.8, 1.0)
# Strength: 0.32
# 255.0 16.0
# Created corrupted image 97, alpha: (0.1, 0.5)
# Strength: 0.63
# 255.0 16.0
# Created corrupted image 97, alpha: (0.5, 0.8)
# Strength: 0.95
# 255.0 16.0
# Created corrupted image 97, alpha: (0.8, 1.0)
# Strength: 0.29
# 255.0 37.0
# Created corrupted image 98, alpha: (0.1, 0.5)
# Strength: 0.6
# 255.0 37.0
# Created corrupted image 98, alpha: (0.5, 0.8)
# Strength: 0.9
# 255.0 37.0
# Created corrupted image 98, alpha: (0.8, 1.0)
# Strength: 0.1
# 255.0 13.0
# Created corrupted image 99, alpha: (0.1, 0.5)
# Strength: 0.64
# 255.0 13.0
# Created corrupted image 99, alpha: (0.5, 0.8)
# Strength: 0.97
# 255.0 13.0
# Created corrupted image 99, alpha: (0.8, 1.0)
# Strength: 0.32
# 255.0 0.0
# Created corrupted image 100, alpha: (0.1, 0.5)
# Strength: 0.64
# 255.0 0.0
# Created corrupted image 100, alpha: (0.5, 0.8)
# Strength: 0.93
# 255.0 0.0
# Created corrupted image 100, alpha: (0.8, 1.0)
# Strength: 0.16
# 222.0 0.0
# Created corrupted image 101, alpha: (0.1, 0.5)
# Strength: 0.71
# 222.0 0.0
# Created corrupted image 101, alpha: (0.5, 0.8)
# Strength: 0.82
# 222.0 0.0
# Created corrupted image 101, alpha: (0.8, 1.0)
# Strength: 0.26
# 146.0 4.0
# Created corrupted image 102, alpha: (0.1, 0.5)
# Strength: 0.68
# 146.0 4.0
# Created corrupted image 102, alpha: (0.5, 0.8)
# Strength: 0.98
# 146.0 4.0
# Created corrupted image 102, alpha: (0.8, 1.0)
# Strength: 0.49
# 254.0 0.0
# Created corrupted image 103, alpha: (0.1, 0.5)
# Strength: 0.67
# 254.0 0.0
# Created corrupted image 103, alpha: (0.5, 0.8)
# Strength: 0.93
# 254.0 0.0
# Created corrupted image 103, alpha: (0.8, 1.0)
# Strength: 0.19
# 229.0 3.0
# Created corrupted image 104, alpha: (0.1, 0.5)
# Strength: 0.71
# 229.0 3.0
# Created corrupted image 104, alpha: (0.5, 0.8)
# Strength: 0.88
# 229.0 3.0
# Created corrupted image 104, alpha: (0.8, 1.0)
# Strength: 0.45
# 245.0 17.0
# Created corrupted image 105, alpha: (0.1, 0.5)
# Strength: 0.73
# 245.0 17.0
# Created corrupted image 105, alpha: (0.5, 0.8)
# Strength: 0.94
# 245.0 17.0
# Created corrupted image 105, alpha: (0.8, 1.0)
# Strength: 0.45
# 239.0 19.0
# Created corrupted image 106, alpha: (0.1, 0.5)
# Strength: 0.78
# 239.0 19.0
# Created corrupted image 106, alpha: (0.5, 0.8)
# Strength: 0.81
# 239.0 19.0
# Created corrupted image 106, alpha: (0.8, 1.0)
# Strength: 0.45
# 207.0 97.0
# Created corrupted image 107, alpha: (0.1, 0.5)
# Strength: 0.61
# 207.0 97.0
# Created corrupted image 107, alpha: (0.5, 0.8)
# Strength: 0.8
# 207.0 97.0
# Created corrupted image 107, alpha: (0.8, 1.0)
# Strength: 0.32
# 255.0 6.0
# Created corrupted image 108, alpha: (0.1, 0.5)
# Strength: 0.65
# 255.0 6.0
# Created corrupted image 108, alpha: (0.5, 0.8)
# Strength: 0.85
# 255.0 6.0
# Created corrupted image 108, alpha: (0.8, 1.0)
# Strength: 0.17
# 224.0 3.0
# Created corrupted image 109, alpha: (0.1, 0.5)
# Strength: 0.73
# 224.0 3.0
# Created corrupted image 109, alpha: (0.5, 0.8)
# Strength: 1.0
# 224.0 3.0
# Created corrupted image 109, alpha: (0.8, 1.0)
# Strength: 0.32
# 255.0 0.0
# Created corrupted image 110, alpha: (0.1, 0.5)
# Strength: 0.53
# 255.0 0.0
# Created corrupted image 110, alpha: (0.5, 0.8)
# Strength: 0.88
# 255.0 0.0
# Created corrupted image 110, alpha: (0.8, 1.0)
# Strength: 0.35
# 255.0 0.0
# Created corrupted image 111, alpha: (0.1, 0.5)
# Strength: 0.78
# 255.0 0.0
# Created corrupted image 111, alpha: (0.5, 0.8)
# Strength: 0.89
# 255.0 0.0
# Created corrupted image 111, alpha: (0.8, 1.0)
# Strength: 0.43
# 215.0 0.0
# Created corrupted image 112, alpha: (0.1, 0.5)
# Strength: 0.71
# 215.0 0.0
# Created corrupted image 112, alpha: (0.5, 0.8)
# Strength: 0.89
# 215.0 0.0
# Created corrupted image 112, alpha: (0.8, 1.0)
# Strength: 0.31
# 242.0 0.0
# Created corrupted image 113, alpha: (0.1, 0.5)
# Strength: 0.52
# 242.0 0.0
# Created corrupted image 113, alpha: (0.5, 0.8)
# Strength: 0.85
# 242.0 0.0
# Created corrupted image 113, alpha: (0.8, 1.0)
# Strength: 0.25
# 255.0 2.0
# Created corrupted image 114, alpha: (0.1, 0.5)
# Strength: 0.64
# 255.0 2.0
# Created corrupted image 114, alpha: (0.5, 0.8)
# Strength: 0.86
# 255.0 2.0
# Created corrupted image 114, alpha: (0.8, 1.0)
# Strength: 0.45
# 255.0 18.0
# Created corrupted image 115, alpha: (0.1, 0.5)
# Strength: 0.72
# 255.0 18.0
# Created corrupted image 115, alpha: (0.5, 0.8)
# Strength: 0.97
# 255.0 18.0
# Created corrupted image 115, alpha: (0.8, 1.0)
# Strength: 0.43
# 255.0 0.0
# Created corrupted image 116, alpha: (0.1, 0.5)
# Strength: 0.68
# 255.0 0.0
# Created corrupted image 116, alpha: (0.5, 0.8)
# Strength: 0.85
# 255.0 0.0
# Created corrupted image 116, alpha: (0.8, 1.0)
# Strength: 0.27
# 210.0 0.0
# Created corrupted image 117, alpha: (0.1, 0.5)
# Strength: 0.76
# 210.0 0.0
# Created corrupted image 117, alpha: (0.5, 0.8)
# Strength: 0.95
# 210.0 0.0
# Created corrupted image 117, alpha: (0.8, 1.0)
# Strength: 0.33
# 244.0 41.0
# Created corrupted image 118, alpha: (0.1, 0.5)
# Strength: 0.8
# 244.0 41.0
# Created corrupted image 118, alpha: (0.5, 0.8)
# Strength: 0.95
# 244.0 41.0
# Created corrupted image 118, alpha: (0.8, 1.0)
# Strength: 0.37
# 255.0 0.0
# Created corrupted image 119, alpha: (0.1, 0.5)
# Strength: 0.76
# 255.0 0.0
# Created corrupted image 119, alpha: (0.5, 0.8)
# Strength: 0.94
# 255.0 0.0
# Created corrupted image 119, alpha: (0.8, 1.0)
# Strength: 0.22
# 255.0 59.0
# Created corrupted image 120, alpha: (0.1, 0.5)
# Strength: 0.65
# 255.0 59.0
# Created corrupted image 120, alpha: (0.5, 0.8)
# Strength: 0.85
# 255.0 59.0
# Created corrupted image 120, alpha: (0.8, 1.0)
# Strength: 0.42
# 243.0 0.0
# Created corrupted image 121, alpha: (0.1, 0.5)
# Strength: 0.71
# 243.0 0.0
# Created corrupted image 121, alpha: (0.5, 0.8)
# Strength: 0.99
# 243.0 0.0
# Created corrupted image 121, alpha: (0.8, 1.0)
# Strength: 0.38
# 255.0 0.0
# Created corrupted image 122, alpha: (0.1, 0.5)
# Strength: 0.61
# 255.0 0.0
# Created corrupted image 122, alpha: (0.5, 0.8)
# Strength: 0.92
# 255.0 0.0
# Created corrupted image 122, alpha: (0.8, 1.0)
# Strength: 0.49
# 231.0 115.0
# Created corrupted image 123, alpha: (0.1, 0.5)
# Strength: 0.72
# 231.0 115.0
# Created corrupted image 123, alpha: (0.5, 0.8)
# Strength: 0.9
# 231.0 115.0
# Created corrupted image 123, alpha: (0.8, 1.0)
# Strength: 0.42
# 255.0 21.0
# Created corrupted image 124, alpha: (0.1, 0.5)
# Strength: 0.55
# 255.0 21.0
# Created corrupted image 124, alpha: (0.5, 0.8)
# Strength: 0.89
# 255.0 21.0
# Created corrupted image 124, alpha: (0.8, 1.0)
# Strength: 0.43
# 235.0 56.0
# Created corrupted image 125, alpha: (0.1, 0.5)
# Strength: 0.51
# 235.0 56.0
# Created corrupted image 125, alpha: (0.5, 0.8)
# Strength: 0.94
# 235.0 56.0
# Created corrupted image 125, alpha: (0.8, 1.0)
# Strength: 0.19
# 255.0 0.0
# Created corrupted image 126, alpha: (0.1, 0.5)
# Strength: 0.77
# 255.0 0.0
# Created corrupted image 126, alpha: (0.5, 0.8)
# Strength: 0.82
# 255.0 0.0
# Created corrupted image 126, alpha: (0.8, 1.0)
# Strength: 0.22
# 251.0 20.0
# Created corrupted image 127, alpha: (0.1, 0.5)
# Strength: 0.68
# 251.0 20.0
# Created corrupted image 127, alpha: (0.5, 0.8)
# Strength: 0.86
# 251.0 20.0
# Created corrupted image 127, alpha: (0.8, 1.0)
# Strength: 0.46
# 239.0 28.0
# Created corrupted image 128, alpha: (0.1, 0.5)
# Strength: 0.79
# 239.0 28.0
# Created corrupted image 128, alpha: (0.5, 0.8)
# Strength: 0.96
# 239.0 28.0
# Created corrupted image 128, alpha: (0.8, 1.0)
# Strength: 0.27
# 249.0 15.0
# Created corrupted image 129, alpha: (0.1, 0.5)
# Strength: 0.67
# 249.0 15.0
# Created corrupted image 129, alpha: (0.5, 0.8)
# Strength: 0.89
# 249.0 15.0
# Created corrupted image 129, alpha: (0.8, 1.0)
# Strength: 0.3
# 181.0 0.0
# Created corrupted image 130, alpha: (0.1, 0.5)
# Strength: 0.75
# 181.0 0.0
# Created corrupted image 130, alpha: (0.5, 0.8)
# Strength: 0.89
# 181.0 0.0
# Created corrupted image 130, alpha: (0.8, 1.0)
# Strength: 0.22
# 211.0 0.0
# Created corrupted image 131, alpha: (0.1, 0.5)
# Strength: 0.61
# 211.0 0.0
# Created corrupted image 131, alpha: (0.5, 0.8)
# Strength: 0.83
# 211.0 0.0
# Created corrupted image 131, alpha: (0.8, 1.0)
# Strength: 0.23
# 255.0 6.0
# Created corrupted image 132, alpha: (0.1, 0.5)
# Strength: 0.52
# 255.0 6.0
# Created corrupted image 132, alpha: (0.5, 0.8)
# Strength: 1.0
# 255.0 6.0
# Created corrupted image 132, alpha: (0.8, 1.0)
# Strength: 0.14
# 255.0 0.0
# Created corrupted image 133, alpha: (0.1, 0.5)
# Strength: 0.75
# 255.0 0.0
# Created corrupted image 133, alpha: (0.5, 0.8)
# Strength: 0.87
# 255.0 0.0
# Created corrupted image 133, alpha: (0.8, 1.0)
# Strength: 0.31
# 255.0 0.0
# Created corrupted image 134, alpha: (0.1, 0.5)
# Strength: 0.77
# 255.0 0.0
# Created corrupted image 134, alpha: (0.5, 0.8)
# Strength: 0.82
# 255.0 0.0
# Created corrupted image 134, alpha: (0.8, 1.0)
# Strength: 0.34
# 255.0 0.0
# Created corrupted image 135, alpha: (0.1, 0.5)
# Strength: 0.69
# 255.0 0.0
# Created corrupted image 135, alpha: (0.5, 0.8)
# Strength: 0.83
# 255.0 0.0
# Created corrupted image 135, alpha: (0.8, 1.0)
# Strength: 0.11
# 224.0 12.0
# Created corrupted image 136, alpha: (0.1, 0.5)
# Strength: 0.55
# 224.0 12.0
# Created corrupted image 136, alpha: (0.5, 0.8)
# Strength: 0.92
# 224.0 12.0
# Created corrupted image 136, alpha: (0.8, 1.0)
# Strength: 0.19
# 246.0 25.0
# Created corrupted image 137, alpha: (0.1, 0.5)
# Strength: 0.68
# 246.0 25.0
# Created corrupted image 137, alpha: (0.5, 0.8)
# Strength: 0.88
# 246.0 25.0
# Created corrupted image 137, alpha: (0.8, 1.0)
# Strength: 0.46
# 255.0 0.0
# Created corrupted image 138, alpha: (0.1, 0.5)
# Strength: 0.59
# 255.0 0.0
# Created corrupted image 138, alpha: (0.5, 0.8)
# Strength: 0.82
# 255.0 0.0
# Created corrupted image 138, alpha: (0.8, 1.0)
# Strength: 0.17
# 255.0 28.0
# Created corrupted image 139, alpha: (0.1, 0.5)
# Strength: 0.69
# 255.0 28.0
# Created corrupted image 139, alpha: (0.5, 0.8)
# Strength: 0.99
# 255.0 28.0
# Created corrupted image 139, alpha: (0.8, 1.0)
# Strength: 0.36
# 218.0 8.0
# Created corrupted image 140, alpha: (0.1, 0.5)
# Strength: 0.8
# 218.0 8.0
# Created corrupted image 140, alpha: (0.5, 0.8)
# Strength: 0.95
# 218.0 8.0
# Created corrupted image 140, alpha: (0.8, 1.0)
# Strength: 0.23
# 255.0 171.0
# Created corrupted image 141, alpha: (0.1, 0.5)
# Strength: 0.76
# 255.0 171.0
# Created corrupted image 141, alpha: (0.5, 0.8)
# Strength: 0.84
# 255.0 171.0
# Created corrupted image 141, alpha: (0.8, 1.0)
# Strength: 0.13
# 250.0 45.0
# Created corrupted image 142, alpha: (0.1, 0.5)
# Strength: 0.52
# 250.0 45.0
# Created corrupted image 142, alpha: (0.5, 0.8)
# Strength: 0.97
# 250.0 45.0
# Created corrupted image 142, alpha: (0.8, 1.0)
# Strength: 0.27
# 255.0 0.0
# Created corrupted image 143, alpha: (0.1, 0.5)
# Strength: 0.56
# 255.0 0.0
# Created corrupted image 143, alpha: (0.5, 0.8)
# Strength: 0.87
# 255.0 0.0
# Created corrupted image 143, alpha: (0.8, 1.0)
# Strength: 0.28
# 255.0 59.0
# Created corrupted image 144, alpha: (0.1, 0.5)
# Strength: 0.64
# 255.0 59.0
# Created corrupted image 144, alpha: (0.5, 0.8)
# Strength: 0.85
# 255.0 59.0
# Created corrupted image 144, alpha: (0.8, 1.0)
# Strength: 0.4
# 255.0 0.0
# Created corrupted image 145, alpha: (0.1, 0.5)
# Strength: 0.54
# 255.0 0.0
# Created corrupted image 145, alpha: (0.5, 0.8)
# Strength: 0.81
# 255.0 0.0
# Created corrupted image 145, alpha: (0.8, 1.0)
# Strength: 0.23
# 178.0 10.0
# Created corrupted image 146, alpha: (0.1, 0.5)
# Strength: 0.73
# 178.0 10.0
# Created corrupted image 146, alpha: (0.5, 0.8)
# Strength: 0.85
# 178.0 10.0
# Created corrupted image 146, alpha: (0.8, 1.0)
# Strength: 0.14
# 255.0 0.0
# Created corrupted image 147, alpha: (0.1, 0.5)
# Strength: 0.63
# 255.0 0.0
# Created corrupted image 147, alpha: (0.5, 0.8)
# Strength: 0.9
# 255.0 0.0
# Created corrupted image 147, alpha: (0.8, 1.0)
# Strength: 0.41
# 247.0 0.0
# Created corrupted image 148, alpha: (0.1, 0.5)
# Strength: 0.77
# 247.0 0.0
# Created corrupted image 148, alpha: (0.5, 0.8)
# Strength: 0.94
# 247.0 0.0
# Created corrupted image 148, alpha: (0.8, 1.0)
# Strength: 0.11
# 225.0 35.0
# Created corrupted image 149, alpha: (0.1, 0.5)
# Strength: 0.66
# 225.0 35.0
# Created corrupted image 149, alpha: (0.5, 0.8)
# Strength: 1.0
# 225.0 35.0
# Created corrupted image 149, alpha: (0.8, 1.0)
# Strength: 0.21
# 255.0 72.0
# Created corrupted image 150, alpha: (0.1, 0.5)
# Strength: 0.75
# 255.0 72.0
# Created corrupted image 150, alpha: (0.5, 0.8)
# Strength: 0.97
# 255.0 72.0
# Created corrupted image 150, alpha: (0.8, 1.0)
# Strength: 0.49
# 255.0 7.0
# Created corrupted image 151, alpha: (0.1, 0.5)
# Strength: 0.74
# 255.0 7.0
# Created corrupted image 151, alpha: (0.5, 0.8)
# Strength: 0.83
# 255.0 7.0
# Created corrupted image 151, alpha: (0.8, 1.0)
# Strength: 0.45
# 255.0 0.0
# Created corrupted image 152, alpha: (0.1, 0.5)
# Strength: 0.69
# 255.0 0.0
# Created corrupted image 152, alpha: (0.5, 0.8)
# Strength: 0.81
# 255.0 0.0
# Created corrupted image 152, alpha: (0.8, 1.0)
# Strength: 0.26
# 74.0 4.0
# Created corrupted image 153, alpha: (0.1, 0.5)
# Strength: 0.79
# 74.0 4.0
# Created corrupted image 153, alpha: (0.5, 0.8)
# Strength: 0.85
# 74.0 4.0
# Created corrupted image 153, alpha: (0.8, 1.0)
# Strength: 0.23
# 251.0 0.0
# Created corrupted image 154, alpha: (0.1, 0.5)
# Strength: 0.55
# 251.0 0.0
# Created corrupted image 154, alpha: (0.5, 0.8)
# Strength: 0.92
# 251.0 0.0
# Created corrupted image 154, alpha: (0.8, 1.0)
# Strength: 0.14
# 233.0 37.0
# Created corrupted image 155, alpha: (0.1, 0.5)
# Strength: 0.66
# 233.0 37.0
# Created corrupted image 155, alpha: (0.5, 0.8)
# Strength: 0.91
# 233.0 37.0
# Created corrupted image 155, alpha: (0.8, 1.0)
# Strength: 0.36
# 221.0 0.0
# Created corrupted image 156, alpha: (0.1, 0.5)
# Strength: 0.51
# 221.0 0.0
# Created corrupted image 156, alpha: (0.5, 0.8)
# Strength: 0.84
# 221.0 0.0
# Created corrupted image 156, alpha: (0.8, 1.0)
# Strength: 0.43
# 234.0 8.0
# Created corrupted image 157, alpha: (0.1, 0.5)
# Strength: 0.76
# 234.0 8.0
# Created corrupted image 157, alpha: (0.5, 0.8)
# Strength: 0.87
# 234.0 8.0
# Created corrupted image 157, alpha: (0.8, 1.0)
# Strength: 0.45
# 217.0 23.0
# Created corrupted image 158, alpha: (0.1, 0.5)
# Strength: 0.77
# 217.0 23.0
# Created corrupted image 158, alpha: (0.5, 0.8)
# Strength: 0.98
# 217.0 23.0
# Created corrupted image 158, alpha: (0.8, 1.0)
# Strength: 0.27
# 219.0 19.0
# Created corrupted image 159, alpha: (0.1, 0.5)
# Strength: 0.63
# 219.0 19.0
# Created corrupted image 159, alpha: (0.5, 0.8)
# Strength: 0.97
# 219.0 19.0
# Created corrupted image 159, alpha: (0.8, 1.0)
# Strength: 0.46
# 227.0 0.0
# Created corrupted image 160, alpha: (0.1, 0.5)
# Strength: 0.62
# 227.0 0.0
# Created corrupted image 160, alpha: (0.5, 0.8)
# Strength: 0.85
# 227.0 0.0
# Created corrupted image 160, alpha: (0.8, 1.0)
# Strength: 0.26
# 255.0 0.0
# Created corrupted image 161, alpha: (0.1, 0.5)
# Strength: 0.63
# 255.0 0.0
# Created corrupted image 161, alpha: (0.5, 0.8)
# Strength: 0.8
# 255.0 0.0
# Created corrupted image 161, alpha: (0.8, 1.0)
# Strength: 0.19
# 224.0 3.0
# Created corrupted image 162, alpha: (0.1, 0.5)
# Strength: 0.6
# 224.0 3.0
# Created corrupted image 162, alpha: (0.5, 0.8)
# Strength: 0.88
# 224.0 3.0
# Created corrupted image 162, alpha: (0.8, 1.0)
# Strength: 0.3
# 255.0 0.0
# Created corrupted image 163, alpha: (0.1, 0.5)
# Strength: 0.75
# 255.0 0.0
# Created corrupted image 163, alpha: (0.5, 0.8)
# Strength: 0.81
# 255.0 0.0
# Created corrupted image 163, alpha: (0.8, 1.0)
# Strength: 0.38
# 255.0 0.0
# Created corrupted image 164, alpha: (0.1, 0.5)
# Strength: 0.79
# 255.0 0.0
# Created corrupted image 164, alpha: (0.5, 0.8)
# Strength: 0.92
# 255.0 0.0
# Created corrupted image 164, alpha: (0.8, 1.0)
# Strength: 0.38
# 255.0 0.0
# Created corrupted image 165, alpha: (0.1, 0.5)
# Strength: 0.62
# 255.0 0.0
# Created corrupted image 165, alpha: (0.5, 0.8)
# Strength: 0.92
# 255.0 0.0
# Created corrupted image 165, alpha: (0.8, 1.0)
# Strength: 0.11
# 181.0 0.0
# Created corrupted image 166, alpha: (0.1, 0.5)
# Strength: 0.76
# 181.0 0.0
# Created corrupted image 166, alpha: (0.5, 0.8)
# Strength: 0.89
# 181.0 0.0
# Created corrupted image 166, alpha: (0.8, 1.0)
# Strength: 0.3
# 239.0 68.0
# Created corrupted image 167, alpha: (0.1, 0.5)
# Strength: 0.76
# 239.0 68.0
# Created corrupted image 167, alpha: (0.5, 0.8)
# Strength: 0.89
# 239.0 68.0
# Created corrupted image 167, alpha: (0.8, 1.0)
# Strength: 0.24
# 195.0 20.0
# Created corrupted image 168, alpha: (0.1, 0.5)
# Strength: 0.52
# 195.0 20.0
# Created corrupted image 168, alpha: (0.5, 0.8)
# Strength: 0.91
# 195.0 20.0
# Created corrupted image 168, alpha: (0.8, 1.0)
# Strength: 0.19
# 239.0 6.0
# Created corrupted image 169, alpha: (0.1, 0.5)
# Strength: 0.62
# 239.0 6.0
# Created corrupted image 169, alpha: (0.5, 0.8)
# Strength: 0.82
# 239.0 6.0
# Created corrupted image 169, alpha: (0.8, 1.0)
# Strength: 0.44
# 253.0 1.0
# Created corrupted image 170, alpha: (0.1, 0.5)
# Strength: 0.79
# 253.0 1.0
# Created corrupted image 170, alpha: (0.5, 0.8)
# Strength: 0.93
# 253.0 1.0
# Created corrupted image 170, alpha: (0.8, 1.0)
# Strength: 0.14
# 178.0 0.0
# Created corrupted image 171, alpha: (0.1, 0.5)
# Strength: 0.5
# 178.0 0.0
# Created corrupted image 171, alpha: (0.5, 0.8)
# Strength: 0.86
# 178.0 0.0
# Created corrupted image 171, alpha: (0.8, 1.0)
# Strength: 0.27
# 255.0 9.0
# Created corrupted image 172, alpha: (0.1, 0.5)
# Strength: 0.78
# 255.0 9.0
# Created corrupted image 172, alpha: (0.5, 0.8)
# Strength: 0.86
# 255.0 9.0
# Created corrupted image 172, alpha: (0.8, 1.0)
# Strength: 0.13
# 205.0 39.0
# Created corrupted image 173, alpha: (0.1, 0.5)
# Strength: 0.67
# 205.0 39.0
# Created corrupted image 173, alpha: (0.5, 0.8)
# Strength: 0.97
# 205.0 39.0
# Created corrupted image 173, alpha: (0.8, 1.0)
# Strength: 0.39
# 229.0 1.0
# Created corrupted image 174, alpha: (0.1, 0.5)
# Strength: 0.53
# 229.0 1.0
# Created corrupted image 174, alpha: (0.5, 0.8)
# Strength: 0.96
# 229.0 1.0
# Created corrupted image 174, alpha: (0.8, 1.0)
# Strength: 0.48
# 255.0 15.0
# Created corrupted image 175, alpha: (0.1, 0.5)
# Strength: 0.68
# 255.0 15.0
# Created corrupted image 175, alpha: (0.5, 0.8)
# Strength: 0.95
# 255.0 15.0
# Created corrupted image 175, alpha: (0.8, 1.0)
# Strength: 0.41
# 255.0 23.0
# Created corrupted image 176, alpha: (0.1, 0.5)
# Strength: 0.74
# 255.0 23.0
# Created corrupted image 176, alpha: (0.5, 0.8)
# Strength: 0.99
# 255.0 23.0
# Created corrupted image 176, alpha: (0.8, 1.0)
# Strength: 0.5
# 179.0 0.0
# Created corrupted image 177, alpha: (0.1, 0.5)
# Strength: 0.5
# 179.0 0.0
# Created corrupted image 177, alpha: (0.5, 0.8)
# Strength: 1.0
# 179.0 0.0
# Created corrupted image 177, alpha: (0.8, 1.0)
# Strength: 0.35
# 255.0 13.0
# Created corrupted image 178, alpha: (0.1, 0.5)
# Strength: 0.7
# 255.0 13.0
# Created corrupted image 178, alpha: (0.5, 0.8)
# Strength: 1.0
# 255.0 13.0
# Created corrupted image 178, alpha: (0.8, 1.0)
# Strength: 0.1
# 231.0 91.0
# Created corrupted image 179, alpha: (0.1, 0.5)
# Strength: 0.5
# 231.0 91.0
# Created corrupted image 179, alpha: (0.5, 0.8)
# Strength: 0.85
# 231.0 91.0
# Created corrupted image 179, alpha: (0.8, 1.0)
# Strength: 0.48
# 255.0 0.0
# Created corrupted image 180, alpha: (0.1, 0.5)
# Strength: 0.76
# 255.0 0.0
# Created corrupted image 180, alpha: (0.5, 0.8)
# Strength: 0.8
# 255.0 0.0
# Created corrupted image 180, alpha: (0.8, 1.0)
# Strength: 0.32
# 163.0 0.0
# Created corrupted image 181, alpha: (0.1, 0.5)
# Strength: 0.55
# 163.0 0.0
# Created corrupted image 181, alpha: (0.5, 0.8)
# Strength: 0.83
# 163.0 0.0
# Created corrupted image 181, alpha: (0.8, 1.0)
# Strength: 0.44
# 246.0 0.0
# Created corrupted image 182, alpha: (0.1, 0.5)
# Strength: 0.75
# 246.0 0.0
# Created corrupted image 182, alpha: (0.5, 0.8)
# Strength: 0.99
# 246.0 0.0
# Created corrupted image 182, alpha: (0.8, 1.0)
# Strength: 0.5
# 255.0 0.0
# Created corrupted image 183, alpha: (0.1, 0.5)
# Strength: 0.69
# 255.0 0.0
# Created corrupted image 183, alpha: (0.5, 0.8)
# Strength: 0.99
# 255.0 0.0
# Created corrupted image 183, alpha: (0.8, 1.0)
# Strength: 0.23
# 255.0 0.0
# Created corrupted image 184, alpha: (0.1, 0.5)
# Strength: 0.57
# 255.0 0.0
# Created corrupted image 184, alpha: (0.5, 0.8)
# Strength: 0.83
# 255.0 0.0
# Created corrupted image 184, alpha: (0.8, 1.0)
# Strength: 0.11
# 251.0 30.0
# Created corrupted image 185, alpha: (0.1, 0.5)
# Strength: 0.53
# 251.0 30.0
# Created corrupted image 185, alpha: (0.5, 0.8)
# Strength: 0.85
# 251.0 30.0
# Created corrupted image 185, alpha: (0.8, 1.0)
# Strength: 0.3
# 255.0 0.0
# Created corrupted image 186, alpha: (0.1, 0.5)
# Strength: 0.57
# 255.0 0.0
# Created corrupted image 186, alpha: (0.5, 0.8)
# Strength: 0.94
# 255.0 0.0
# Created corrupted image 186, alpha: (0.8, 1.0)
# Strength: 0.41
# 255.0 0.0
# Created corrupted image 187, alpha: (0.1, 0.5)
# Strength: 0.58
# 255.0 0.0
# Created corrupted image 187, alpha: (0.5, 0.8)
# Strength: 0.89
# 255.0 0.0
# Created corrupted image 187, alpha: (0.8, 1.0)
# Strength: 0.18
# 255.0 0.0
# Created corrupted image 188, alpha: (0.1, 0.5)
# Strength: 0.63
# 255.0 0.0
# Created corrupted image 188, alpha: (0.5, 0.8)
# Strength: 0.98
# 255.0 0.0
# Created corrupted image 188, alpha: (0.8, 1.0)
# Strength: 0.12
# 234.0 9.0
# Created corrupted image 189, alpha: (0.1, 0.5)
# Strength: 0.56
# 234.0 9.0
# Created corrupted image 189, alpha: (0.5, 0.8)
# Strength: 0.81
# 234.0 9.0
# Created corrupted image 189, alpha: (0.8, 1.0)
# Strength: 0.32
# 235.0 0.0
# Created corrupted image 190, alpha: (0.1, 0.5)
# Strength: 0.78
# 235.0 0.0
# Created corrupted image 190, alpha: (0.5, 0.8)
# Strength: 0.98
# 235.0 0.0
# Created corrupted image 190, alpha: (0.8, 1.0)
# Strength: 0.38
# 237.0 0.0
# Created corrupted image 191, alpha: (0.1, 0.5)
# Strength: 0.61
# 237.0 0.0
# Created corrupted image 191, alpha: (0.5, 0.8)
# Strength: 0.93
# 237.0 0.0
# Created corrupted image 191, alpha: (0.8, 1.0)
# Strength: 0.39
# 255.0 0.0
# Created corrupted image 192, alpha: (0.1, 0.5)
# Strength: 0.68
# 255.0 0.0
# Created corrupted image 192, alpha: (0.5, 0.8)
# Strength: 0.83
# 255.0 0.0
# Created corrupted image 192, alpha: (0.8, 1.0)
# Strength: 0.22
# 237.0 17.0
# Created corrupted image 193, alpha: (0.1, 0.5)
# Strength: 0.74
# 237.0 17.0
# Created corrupted image 193, alpha: (0.5, 0.8)
# Strength: 0.82
# 237.0 17.0
# Created corrupted image 193, alpha: (0.8, 1.0)
# Strength: 0.25
# 212.0 9.0
# Created corrupted image 194, alpha: (0.1, 0.5)
# Strength: 0.56
# 212.0 9.0
# Created corrupted image 194, alpha: (0.5, 0.8)
# Strength: 0.89
# 212.0 9.0
# Created corrupted image 194, alpha: (0.8, 1.0)
# Strength: 0.27
# 255.0 0.0
# Created corrupted image 195, alpha: (0.1, 0.5)
# Strength: 0.67
# 255.0 0.0
# Created corrupted image 195, alpha: (0.5, 0.8)
# Strength: 0.86
# 255.0 0.0
# Created corrupted image 195, alpha: (0.8, 1.0)
# Strength: 0.38
# 255.0 26.0
# Created corrupted image 196, alpha: (0.1, 0.5)
# Strength: 0.66
# 255.0 26.0
# Created corrupted image 196, alpha: (0.5, 0.8)
# Strength: 0.9
# 255.0 26.0
# Created corrupted image 196, alpha: (0.8, 1.0)
# Strength: 0.23
# 240.0 0.0
# Created corrupted image 197, alpha: (0.1, 0.5)
# Strength: 0.61
# 240.0 0.0
# Created corrupted image 197, alpha: (0.5, 0.8)
# Strength: 0.85
# 240.0 0.0
# Created corrupted image 197, alpha: (0.8, 1.0)
# Strength: 0.32
# 255.0 40.0
# Created corrupted image 198, alpha: (0.1, 0.5)
# Strength: 0.53
# 255.0 40.0
# Created corrupted image 198, alpha: (0.5, 0.8)
# Strength: 0.98
# 255.0 40.0
# Created corrupted image 198, alpha: (0.8, 1.0)
# Strength: 0.35
# 255.0 0.0
# Created corrupted image 199, alpha: (0.1, 0.5)
# Strength: 0.62
# 255.0 0.0
# Created corrupted image 199, alpha: (0.5, 0.8)
# Strength: 0.96
# 255.0 0.0
# Created corrupted image 199, alpha: (0.8, 1.0)
# Strength: 0.16
# 230.0 4.0
# Created corrupted image 200, alpha: (0.1, 0.5)
# Strength: 0.57
# 230.0 4.0
# Created corrupted image 200, alpha: (0.5, 0.8)
# Strength: 0.83
# 230.0 4.0
# Created corrupted image 200, alpha: (0.8, 1.0)
# Strength: 0.33
# 242.0 26.0
# Created corrupted image 201, alpha: (0.1, 0.5)
# Strength: 0.7
# 242.0 26.0
# Created corrupted image 201, alpha: (0.5, 0.8)
# Strength: 0.81
# 242.0 26.0
# Created corrupted image 201, alpha: (0.8, 1.0)
# Strength: 0.31
# 241.0 77.0
# Created corrupted image 202, alpha: (0.1, 0.5)
# Strength: 0.71
# 241.0 77.0
# Created corrupted image 202, alpha: (0.5, 0.8)
# Strength: 0.88
# 241.0 77.0
# Created corrupted image 202, alpha: (0.8, 1.0)
# Strength: 0.45
# 255.0 0.0
# Created corrupted image 203, alpha: (0.1, 0.5)
# Strength: 0.79
# 255.0 0.0
# Created corrupted image 203, alpha: (0.5, 0.8)
# Strength: 0.82
# 255.0 0.0
# Created corrupted image 203, alpha: (0.8, 1.0)
# Strength: 0.12
# 237.0 0.0
# Created corrupted image 204, alpha: (0.1, 0.5)
# Strength: 0.65
# 237.0 0.0
# Created corrupted image 204, alpha: (0.5, 0.8)
# Strength: 0.94
# 237.0 0.0
# Created corrupted image 204, alpha: (0.8, 1.0)
# Strength: 0.29
# 255.0 0.0
# Created corrupted image 205, alpha: (0.1, 0.5)
# Strength: 0.72
# 255.0 0.0
# Created corrupted image 205, alpha: (0.5, 0.8)
# Strength: 0.9
# 255.0 0.0
# Created corrupted image 205, alpha: (0.8, 1.0)
# Strength: 0.14
# 255.0 0.0
# Created corrupted image 206, alpha: (0.1, 0.5)
# Strength: 0.78
# 255.0 0.0
# Created corrupted image 206, alpha: (0.5, 0.8)
# Strength: 0.86
# 255.0 0.0
# Created corrupted image 206, alpha: (0.8, 1.0)
# Strength: 0.36
# 255.0 0.0
# Created corrupted image 207, alpha: (0.1, 0.5)
# Strength: 0.52
# 255.0 0.0
# Created corrupted image 207, alpha: (0.5, 0.8)
# Strength: 0.8
# 255.0 0.0
# Created corrupted image 207, alpha: (0.8, 1.0)
# Strength: 0.24
# 255.0 0.0
# Created corrupted image 208, alpha: (0.1, 0.5)
# Strength: 0.73
# 255.0 0.0
# Created corrupted image 208, alpha: (0.5, 0.8)
# Strength: 0.8
# 255.0 0.0
# Created corrupted image 208, alpha: (0.8, 1.0)
# Strength: 0.13
# 255.0 2.0
# Created corrupted image 209, alpha: (0.1, 0.5)
# Strength: 0.56
# 255.0 2.0
# Created corrupted image 209, alpha: (0.5, 0.8)
# Strength: 0.82
# 255.0 2.0
# Created corrupted image 209, alpha: (0.8, 1.0)
# Strength: 0.41
# 246.0 2.0
# Created corrupted image 210, alpha: (0.1, 0.5)
# Strength: 0.57
# 246.0 2.0
# Created corrupted image 210, alpha: (0.5, 0.8)
# Strength: 0.83
# 246.0 2.0
# Created corrupted image 210, alpha: (0.8, 1.0)
# Strength: 0.35
# 255.0 25.0
# Created corrupted image 211, alpha: (0.1, 0.5)
# Strength: 0.51
# 255.0 25.0
# Created corrupted image 211, alpha: (0.5, 0.8)
# Strength: 0.88
# 255.0 25.0
# Created corrupted image 211, alpha: (0.8, 1.0)
# Strength: 0.35
# 255.0 16.0
# Created corrupted image 212, alpha: (0.1, 0.5)
# Strength: 0.78
# 255.0 16.0
# Created corrupted image 212, alpha: (0.5, 0.8)
# Strength: 0.89
# 255.0 16.0
# Created corrupted image 212, alpha: (0.8, 1.0)
# Strength: 0.25
# 255.0 25.0
# Created corrupted image 213, alpha: (0.1, 0.5)
# Strength: 0.74
# 255.0 25.0
# Created corrupted image 213, alpha: (0.5, 0.8)
# Strength: 0.91
# 255.0 25.0
# Created corrupted image 213, alpha: (0.8, 1.0)
# Strength: 0.36
# 255.0 0.0
# Created corrupted image 214, alpha: (0.1, 0.5)
# Strength: 0.66
# 255.0 0.0
# Created corrupted image 214, alpha: (0.5, 0.8)
# Strength: 0.85
# 255.0 0.0
# Created corrupted image 214, alpha: (0.8, 1.0)
# Strength: 0.47
# 246.0 10.0
# Created corrupted image 215, alpha: (0.1, 0.5)
# Strength: 0.53
# 246.0 10.0
# Created corrupted image 215, alpha: (0.5, 0.8)
# Strength: 0.97
# 246.0 10.0
# Created corrupted image 215, alpha: (0.8, 1.0)
# Strength: 0.44
# 252.0 6.0
# Created corrupted image 216, alpha: (0.1, 0.5)
# Strength: 0.54
# 252.0 6.0
# Created corrupted image 216, alpha: (0.5, 0.8)
# Strength: 0.93
# 252.0 6.0
# Created corrupted image 216, alpha: (0.8, 1.0)
# Strength: 0.35
# 255.0 0.0
# Created corrupted image 217, alpha: (0.1, 0.5)
# Strength: 0.78
# 255.0 0.0
# Created corrupted image 217, alpha: (0.5, 0.8)
# Strength: 0.89
# 255.0 0.0
# Created corrupted image 217, alpha: (0.8, 1.0)
# Strength: 0.29
# 255.0 0.0
# Created corrupted image 218, alpha: (0.1, 0.5)
# Strength: 0.76
# 255.0 0.0
# Created corrupted image 218, alpha: (0.5, 0.8)
# Strength: 0.96
# 255.0 0.0
# Created corrupted image 218, alpha: (0.8, 1.0)
# Strength: 0.43
# 255.0 0.0
# Created corrupted image 219, alpha: (0.1, 0.5)
# Strength: 0.79
# 255.0 0.0
# Created corrupted image 219, alpha: (0.5, 0.8)
# Strength: 0.89
# 255.0 0.0
# Created corrupted image 219, alpha: (0.8, 1.0)
# Strength: 0.15
# 255.0 0.0
# Created corrupted image 220, alpha: (0.1, 0.5)
# Strength: 0.73
# 255.0 0.0
# Created corrupted image 220, alpha: (0.5, 0.8)
# Strength: 0.84
# 255.0 0.0
# Created corrupted image 220, alpha: (0.8, 1.0)
# Strength: 0.1
# 249.0 0.0
# Created corrupted image 221, alpha: (0.1, 0.5)
# Strength: 0.51
# 249.0 0.0
# Created corrupted image 221, alpha: (0.5, 0.8)
# Strength: 0.92
# 249.0 0.0
# Created corrupted image 221, alpha: (0.8, 1.0)
# Strength: 0.4
# 252.0 169.0
# Created corrupted image 222, alpha: (0.1, 0.5)
# Strength: 0.58
# 252.0 169.0
# Created corrupted image 222, alpha: (0.5, 0.8)
# Strength: 0.98
# 252.0 169.0
# Created corrupted image 222, alpha: (0.8, 1.0)
# Strength: 0.36
# 255.0 0.0
# Created corrupted image 223, alpha: (0.1, 0.5)
# Strength: 0.68
# 255.0 0.0
# Created corrupted image 223, alpha: (0.5, 0.8)
# Strength: 0.86
# 255.0 0.0
# Created corrupted image 223, alpha: (0.8, 1.0)
# Strength: 0.26
# 255.0 14.0
# Created corrupted image 224, alpha: (0.1, 0.5)
# Strength: 0.68
# 255.0 14.0
# Created corrupted image 224, alpha: (0.5, 0.8)
# Strength: 0.88
# 255.0 14.0
# Created corrupted image 224, alpha: (0.8, 1.0)
# Strength: 0.31
# 240.0 2.0
# Created corrupted image 225, alpha: (0.1, 0.5)
# Strength: 0.61
# 240.0 2.0
# Created corrupted image 225, alpha: (0.5, 0.8)
# Strength: 0.89
# 240.0 2.0
# Created corrupted image 225, alpha: (0.8, 1.0)
# Strength: 0.32
# 241.0 9.0
# Created corrupted image 226, alpha: (0.1, 0.5)
# Strength: 0.52
# 241.0 9.0
# Created corrupted image 226, alpha: (0.5, 0.8)
# Strength: 0.97
# 241.0 9.0
# Created corrupted image 226, alpha: (0.8, 1.0)
# Strength: 0.27
# 253.0 79.0
# Created corrupted image 227, alpha: (0.1, 0.5)
# Strength: 0.8
# 253.0 79.0
# Created corrupted image 227, alpha: (0.5, 0.8)
# Strength: 0.97
# 253.0 79.0
# Created corrupted image 227, alpha: (0.8, 1.0)
# Strength: 0.32
# 255.0 0.0
# Created corrupted image 228, alpha: (0.1, 0.5)
# Strength: 0.7
# 255.0 0.0
# Created corrupted image 228, alpha: (0.5, 0.8)
# Strength: 0.98
# 255.0 0.0
# Created corrupted image 228, alpha: (0.8, 1.0)
# Strength: 0.11
# 210.0 21.0
# Created corrupted image 229, alpha: (0.1, 0.5)
# Strength: 0.56
# 210.0 21.0
# Created corrupted image 229, alpha: (0.5, 0.8)
# Strength: 0.92
# 210.0 21.0
# Created corrupted image 229, alpha: (0.8, 1.0)
# Strength: 0.13
# 255.0 0.0
# Created corrupted image 230, alpha: (0.1, 0.5)
# Strength: 0.79
# 255.0 0.0
# Created corrupted image 230, alpha: (0.5, 0.8)
# Strength: 0.91
# 255.0 0.0
# Created corrupted image 230, alpha: (0.8, 1.0)
# Strength: 0.39
# 255.0 0.0
# Created corrupted image 231, alpha: (0.1, 0.5)
# Strength: 0.54
# 255.0 0.0
# Created corrupted image 231, alpha: (0.5, 0.8)
# Strength: 0.92
# 255.0 0.0
# Created corrupted image 231, alpha: (0.8, 1.0)
# Strength: 0.41
# 255.0 2.0
# Created corrupted image 232, alpha: (0.1, 0.5)
# Strength: 0.62
# 255.0 2.0
# Created corrupted image 232, alpha: (0.5, 0.8)
# Strength: 0.92
# 255.0 2.0
# Created corrupted image 232, alpha: (0.8, 1.0)
# Strength: 0.16
# 255.0 80.0
# Created corrupted image 233, alpha: (0.1, 0.5)
# Strength: 0.55
# 255.0 80.0
# Created corrupted image 233, alpha: (0.5, 0.8)
# Strength: 0.95
# 255.0 80.0
# Created corrupted image 233, alpha: (0.8, 1.0)
# Strength: 0.22
# 255.0 28.0
# Created corrupted image 234, alpha: (0.1, 0.5)
# Strength: 0.63
# 255.0 28.0
# Created corrupted image 234, alpha: (0.5, 0.8)
# Strength: 0.93
# 255.0 28.0
# Created corrupted image 234, alpha: (0.8, 1.0)
# Strength: 0.34
# 244.0 0.0
# Created corrupted image 235, alpha: (0.1, 0.5)
# Strength: 0.75
# 244.0 0.0
# Created corrupted image 235, alpha: (0.5, 0.8)
# Strength: 0.86
# 244.0 0.0
# Created corrupted image 235, alpha: (0.8, 1.0)
# Strength: 0.43
# 255.0 0.0
# Created corrupted image 236, alpha: (0.1, 0.5)
# Strength: 0.75
# 255.0 0.0
# Created corrupted image 236, alpha: (0.5, 0.8)
# Strength: 0.85
# 255.0 0.0
# Created corrupted image 236, alpha: (0.8, 1.0)
# Strength: 0.11
# 255.0 0.0
# Created corrupted image 237, alpha: (0.1, 0.5)
# Strength: 0.62
# 255.0 0.0
# Created corrupted image 237, alpha: (0.5, 0.8)
# Strength: 0.94
# 255.0 0.0
# Created corrupted image 237, alpha: (0.8, 1.0)
# Strength: 0.48
# 255.0 57.0
# Created corrupted image 238, alpha: (0.1, 0.5)
# Strength: 0.7
# 255.0 57.0
# Created corrupted image 238, alpha: (0.5, 0.8)
# Strength: 0.81
# 255.0 57.0
# Created corrupted image 238, alpha: (0.8, 1.0)
# Strength: 0.41
# 224.0 0.0
# Created corrupted image 239, alpha: (0.1, 0.5)
# Strength: 0.6
# 224.0 0.0
# Created corrupted image 239, alpha: (0.5, 0.8)
# Strength: 0.94
# 224.0 0.0
# Created corrupted image 239, alpha: (0.8, 1.0)
# Strength: 0.33
# 255.0 0.0
# Created corrupted image 240, alpha: (0.1, 0.5)
# Strength: 0.55
# 255.0 0.0
# Created corrupted image 240, alpha: (0.5, 0.8)
# Strength: 0.81
# 255.0 0.0
# Created corrupted image 240, alpha: (0.8, 1.0)
# Strength: 0.15
# 220.0 7.0
# Created corrupted image 241, alpha: (0.1, 0.5)
# Strength: 0.77
# 220.0 7.0
# Created corrupted image 241, alpha: (0.5, 0.8)
# Strength: 0.87
# 220.0 7.0
# Created corrupted image 241, alpha: (0.8, 1.0)
# Strength: 0.49
# 240.0 0.0
# Created corrupted image 242, alpha: (0.1, 0.5)
# Strength: 0.61
# 240.0 0.0
# Created corrupted image 242, alpha: (0.5, 0.8)
# Strength: 1.0
# 240.0 0.0
# Created corrupted image 242, alpha: (0.8, 1.0)
# Strength: 0.33
# 255.0 0.0
# Created corrupted image 243, alpha: (0.1, 0.5)
# Strength: 0.7
# 255.0 0.0
# Created corrupted image 243, alpha: (0.5, 0.8)
# Strength: 0.85
# 255.0 0.0
# Created corrupted image 243, alpha: (0.8, 1.0)
# Strength: 0.1
# 255.0 0.0
# Created corrupted image 244, alpha: (0.1, 0.5)
# Strength: 0.72
# 255.0 0.0
# Created corrupted image 244, alpha: (0.5, 0.8)
# Strength: 0.92
# 255.0 0.0
# Created corrupted image 244, alpha: (0.8, 1.0)
# Strength: 0.16
# 255.0 0.0
# Created corrupted image 245, alpha: (0.1, 0.5)
# Strength: 0.69
# 255.0 0.0
# Created corrupted image 245, alpha: (0.5, 0.8)
# Strength: 0.83
# 255.0 0.0
# Created corrupted image 245, alpha: (0.8, 1.0)
# Strength: 0.41
# 255.0 21.0
# Created corrupted image 246, alpha: (0.1, 0.5)
# Strength: 0.53
# 255.0 21.0
# Created corrupted image 246, alpha: (0.5, 0.8)
# Strength: 0.97
# 255.0 21.0
# Created corrupted image 246, alpha: (0.8, 1.0)
# Strength: 0.4
# 255.0 0.0
# Created corrupted image 247, alpha: (0.1, 0.5)
# Strength: 0.56
# 255.0 0.0
# Created corrupted image 247, alpha: (0.5, 0.8)
# Strength: 0.82
# 255.0 0.0
# Created corrupted image 247, alpha: (0.8, 1.0)
# Strength: 0.21
# 255.0 0.0
# Created corrupted image 248, alpha: (0.1, 0.5)
# Strength: 0.79
# 255.0 0.0
# Created corrupted image 248, alpha: (0.5, 0.8)
# Strength: 0.83
# 255.0 0.0
# Created corrupted image 248, alpha: (0.8, 1.0)
# Strength: 0.31
# 255.0 0.0
# Created corrupted image 249, alpha: (0.1, 0.5)
# Strength: 0.71
# 255.0 0.0
# Created corrupted image 249, alpha: (0.5, 0.8)
# Strength: 0.88
# 255.0 0.0
# Created corrupted image 249, alpha: (0.8, 1.0)
# Strength: 0.44
# 255.0 9.0
# Created corrupted image 250, alpha: (0.1, 0.5)
# Strength: 0.74
# 255.0 9.0
# Created corrupted image 250, alpha: (0.5, 0.8)
# Strength: 0.97
# 255.0 9.0
# Created corrupted image 250, alpha: (0.8, 1.0)
# Strength: 0.37
# 255.0 12.0
# Created corrupted image 251, alpha: (0.1, 0.5)
# Strength: 0.52
# 255.0 12.0
# Created corrupted image 251, alpha: (0.5, 0.8)
# Strength: 0.91
# 255.0 12.0
# Created corrupted image 251, alpha: (0.8, 1.0)
# Strength: 0.41
# 248.0 95.0
# Created corrupted image 252, alpha: (0.1, 0.5)
# Strength: 0.66
# 248.0 95.0
# Created corrupted image 252, alpha: (0.5, 0.8)
# Strength: 0.81
# 248.0 95.0
# Created corrupted image 252, alpha: (0.8, 1.0)
# Strength: 0.44
# 235.0 0.0
# Created corrupted image 253, alpha: (0.1, 0.5)
# Strength: 0.8
# 235.0 0.0
# Created corrupted image 253, alpha: (0.5, 0.8)
# Strength: 0.82
# 235.0 0.0
# Created corrupted image 253, alpha: (0.8, 1.0)
# Strength: 0.43
# 255.0 0.0
# Created corrupted image 254, alpha: (0.1, 0.5)
# Strength: 0.67
# 255.0 0.0
# Created corrupted image 254, alpha: (0.5, 0.8)
# Strength: 0.98
# 255.0 0.0
# Created corrupted image 254, alpha: (0.8, 1.0)
# Strength: 0.27
# 255.0 0.0
# Created corrupted image 255, alpha: (0.1, 0.5)
# Strength: 0.74
# 255.0 0.0
# Created corrupted image 255, alpha: (0.5, 0.8)
# Strength: 0.96
# 255.0 0.0
# Created corrupted image 255, alpha: (0.8, 1.0)
# Strength: 0.17
# 255.0 0.0
# Created corrupted image 256, alpha: (0.1, 0.5)
# Strength: 0.78
# 255.0 0.0
# Created corrupted image 256, alpha: (0.5, 0.8)
# Strength: 0.86
# 255.0 0.0
# Created corrupted image 256, alpha: (0.8, 1.0)
# Strength: 0.12
# 160.0 13.0
# Created corrupted image 257, alpha: (0.1, 0.5)
# Strength: 0.76
# 160.0 13.0
# Created corrupted image 257, alpha: (0.5, 0.8)
# Strength: 0.97
# 160.0 13.0
# Created corrupted image 257, alpha: (0.8, 1.0)
# Strength: 0.25
# 220.0 61.0
# Created corrupted image 258, alpha: (0.1, 0.5)
# Strength: 0.74
# 220.0 61.0
# Created corrupted image 258, alpha: (0.5, 0.8)
# Strength: 0.86
# 220.0 61.0
# Created corrupted image 258, alpha: (0.8, 1.0)
# Strength: 0.22
# 255.0 0.0
# Created corrupted image 259, alpha: (0.1, 0.5)
# Strength: 0.6
# 255.0 0.0
# Created corrupted image 259, alpha: (0.5, 0.8)
# Strength: 0.96
# 255.0 0.0
# Created corrupted image 259, alpha: (0.8, 1.0)
# Strength: 0.19
# 255.0 0.0
# Created corrupted image 260, alpha: (0.1, 0.5)
# Strength: 0.73
# 255.0 0.0
# Created corrupted image 260, alpha: (0.5, 0.8)
# Strength: 0.98
# 255.0 0.0
# Created corrupted image 260, alpha: (0.8, 1.0)
# Strength: 0.32
# 221.0 7.0
# Created corrupted image 261, alpha: (0.1, 0.5)
# Strength: 0.62
# 221.0 7.0
# Created corrupted image 261, alpha: (0.5, 0.8)
# Strength: 0.87
# 221.0 7.0
# Created corrupted image 261, alpha: (0.8, 1.0)
# Strength: 0.49
# 225.0 14.0
# Created corrupted image 262, alpha: (0.1, 0.5)
# Strength: 0.56
# 225.0 14.0
# Created corrupted image 262, alpha: (0.5, 0.8)
# Strength: 0.89
# 225.0 14.0
# Created corrupted image 262, alpha: (0.8, 1.0)
# Strength: 0.21
# 250.0 8.0
# Created corrupted image 263, alpha: (0.1, 0.5)
# Strength: 0.55
# 250.0 8.0
# Created corrupted image 263, alpha: (0.5, 0.8)
# Strength: 0.87
# 250.0 8.0
# Created corrupted image 263, alpha: (0.8, 1.0)
# Strength: 0.13
# 249.0 0.0
# Created corrupted image 264, alpha: (0.1, 0.5)
# Strength: 0.74
# 249.0 0.0
# Created corrupted image 264, alpha: (0.5, 0.8)
# Strength: 0.97
# 249.0 0.0
# Created corrupted image 264, alpha: (0.8, 1.0)
# Strength: 0.36
# 241.0 40.0
# Created corrupted image 265, alpha: (0.1, 0.5)
# Strength: 0.77
# 241.0 40.0
# Created corrupted image 265, alpha: (0.5, 0.8)
# Strength: 0.81
# 241.0 40.0
# Created corrupted image 265, alpha: (0.8, 1.0)
# Strength: 0.38
# 244.0 17.0
# Created corrupted image 266, alpha: (0.1, 0.5)
# Strength: 0.69
# 244.0 17.0
# Created corrupted image 266, alpha: (0.5, 0.8)
# Strength: 0.88
# 244.0 17.0
# Created corrupted image 266, alpha: (0.8, 1.0)
# Strength: 0.41
# 255.0 8.0
# Created corrupted image 267, alpha: (0.1, 0.5)
# Strength: 0.64
# 255.0 8.0
# Created corrupted image 267, alpha: (0.5, 0.8)
# Strength: 0.96
# 255.0 8.0
# Created corrupted image 267, alpha: (0.8, 1.0)
# Strength: 0.33
# 218.0 6.0
# Created corrupted image 268, alpha: (0.1, 0.5)
# Strength: 0.54
# 218.0 6.0
# Created corrupted image 268, alpha: (0.5, 0.8)
# Strength: 0.8
# 218.0 6.0
# Created corrupted image 268, alpha: (0.8, 1.0)
# Strength: 0.17
# 255.0 0.0
# Created corrupted image 269, alpha: (0.1, 0.5)
# Strength: 0.6
# 255.0 0.0
# Created corrupted image 269, alpha: (0.5, 0.8)
# Strength: 0.88
# 255.0 0.0
# Created corrupted image 269, alpha: (0.8, 1.0)
# Strength: 0.24
# 255.0 46.0
# Created corrupted image 270, alpha: (0.1, 0.5)
# Strength: 0.65
# 255.0 46.0
# Created corrupted image 270, alpha: (0.5, 0.8)
# Strength: 1.0
# 255.0 46.0
# Created corrupted image 270, alpha: (0.8, 1.0)
# Strength: 0.32
# 255.0 0.0
# Created corrupted image 271, alpha: (0.1, 0.5)
# Strength: 0.73
# 255.0 0.0
# Created corrupted image 271, alpha: (0.5, 0.8)
# Strength: 0.84
# 255.0 0.0
# Created corrupted image 271, alpha: (0.8, 1.0)
# Strength: 0.33
# 255.0 1.0
# Created corrupted image 272, alpha: (0.1, 0.5)
# Strength: 0.79
# 255.0 1.0
# Created corrupted image 272, alpha: (0.5, 0.8)
# Strength: 0.93
# 255.0 1.0
# Created corrupted image 272, alpha: (0.8, 1.0)
# Strength: 0.23
# 255.0 0.0
# Created corrupted image 273, alpha: (0.1, 0.5)
# Strength: 0.57
# 255.0 0.0
# Created corrupted image 273, alpha: (0.5, 0.8)
# Strength: 0.83
# 255.0 0.0
# Created corrupted image 273, alpha: (0.8, 1.0)
# Strength: 0.17
# 255.0 0.0
# Created corrupted image 274, alpha: (0.1, 0.5)
# Strength: 0.72
# 255.0 0.0
# Created corrupted image 274, alpha: (0.5, 0.8)
# Strength: 0.87
# 255.0 0.0
# Created corrupted image 274, alpha: (0.8, 1.0)
# Strength: 0.13
# 210.0 0.0
# Created corrupted image 275, alpha: (0.1, 0.5)
# Strength: 0.59
# 210.0 0.0
# Created corrupted image 275, alpha: (0.5, 0.8)
# Strength: 0.82
# 210.0 0.0
# Created corrupted image 275, alpha: (0.8, 1.0)
# Strength: 0.16
# 255.0 0.0
# Created corrupted image 276, alpha: (0.1, 0.5)
# Strength: 0.69
# 255.0 0.0
# Created corrupted image 276, alpha: (0.5, 0.8)
# Strength: 0.95
# 255.0 0.0
# Created corrupted image 276, alpha: (0.8, 1.0)
# Strength: 0.19
# 251.0 10.0
# Created corrupted image 277, alpha: (0.1, 0.5)
# Strength: 0.66
# 251.0 10.0
# Created corrupted image 277, alpha: (0.5, 0.8)
# Strength: 0.91
# 251.0 10.0
# Created corrupted image 277, alpha: (0.8, 1.0)
# Strength: 0.27
# 229.0 1.0
# Created corrupted image 278, alpha: (0.1, 0.5)
# Strength: 0.74
# 229.0 1.0
# Created corrupted image 278, alpha: (0.5, 0.8)
# Strength: 0.93
# 229.0 1.0
# Created corrupted image 278, alpha: (0.8, 1.0)
# Strength: 0.1
# 255.0 0.0
# Created corrupted image 279, alpha: (0.1, 0.5)
# Strength: 0.69
# 255.0 0.0
# Created corrupted image 279, alpha: (0.5, 0.8)
# Strength: 0.97
# 255.0 0.0
# Created corrupted image 279, alpha: (0.8, 1.0)
# Strength: 0.38
# 255.0 36.0
# Created corrupted image 280, alpha: (0.1, 0.5)
# Strength: 0.78
# 255.0 36.0
# Created corrupted image 280, alpha: (0.5, 0.8)
# Strength: 0.99
# 255.0 36.0
# Created corrupted image 280, alpha: (0.8, 1.0)
# Strength: 0.31
# 252.0 17.0
# Created corrupted image 281, alpha: (0.1, 0.5)
# Strength: 0.62
# 252.0 17.0
# Created corrupted image 281, alpha: (0.5, 0.8)
# Strength: 0.97
# 252.0 17.0
# Created corrupted image 281, alpha: (0.8, 1.0)
# Strength: 0.48
# 124.0 29.0
# Created corrupted image 282, alpha: (0.1, 0.5)
# Strength: 0.59
# 124.0 29.0
# Created corrupted image 282, alpha: (0.5, 0.8)
# Strength: 0.9
# 124.0 29.0
# Created corrupted image 282, alpha: (0.8, 1.0)
# Strength: 0.31
# 255.0 42.0
# Created corrupted image 283, alpha: (0.1, 0.5)
# Strength: 0.59
# 255.0 42.0
# Created corrupted image 283, alpha: (0.5, 0.8)
# Strength: 0.88
# 255.0 42.0
# Created corrupted image 283, alpha: (0.8, 1.0)
# Strength: 0.48
# 255.0 0.0
# Created corrupted image 284, alpha: (0.1, 0.5)
# Strength: 0.54
# 255.0 0.0
# Created corrupted image 284, alpha: (0.5, 0.8)
# Strength: 0.88
# 255.0 0.0
# Created corrupted image 284, alpha: (0.8, 1.0)
# Strength: 0.17
# 224.0 6.0
# Created corrupted image 285, alpha: (0.1, 0.5)
# Strength: 0.75
# 224.0 6.0
# Created corrupted image 285, alpha: (0.5, 0.8)
# Strength: 0.98
# 224.0 6.0
# Created corrupted image 285, alpha: (0.8, 1.0)
# Strength: 0.48
# 255.0 0.0
# Created corrupted image 286, alpha: (0.1, 0.5)
# Strength: 0.67
# 255.0 0.0
# Created corrupted image 286, alpha: (0.5, 0.8)
# Strength: 0.95
# 255.0 0.0
# Created corrupted image 286, alpha: (0.8, 1.0)
# Strength: 0.17
# 255.0 80.0
# Created corrupted image 287, alpha: (0.1, 0.5)
# Strength: 0.53
# 255.0 80.0
# Created corrupted image 287, alpha: (0.5, 0.8)
# Strength: 0.86
# 255.0 80.0
# Created corrupted image 287, alpha: (0.8, 1.0)
# Strength: 0.32
# 239.0 61.0
# Created corrupted image 288, alpha: (0.1, 0.5)
# Strength: 0.72
# 239.0 61.0
# Created corrupted image 288, alpha: (0.5, 0.8)
# Strength: 0.88
# 239.0 61.0
# Created corrupted image 288, alpha: (0.8, 1.0)
# Strength: 0.37
# 255.0 19.0
# Created corrupted image 289, alpha: (0.1, 0.5)
# Strength: 0.78
# 255.0 19.0
# Created corrupted image 289, alpha: (0.5, 0.8)
# Strength: 0.98
# 255.0 19.0
# Created corrupted image 289, alpha: (0.8, 1.0)
# Strength: 0.37
# 255.0 62.0
# Created corrupted image 290, alpha: (0.1, 0.5)
# Strength: 0.51
# 255.0 62.0
# Created corrupted image 290, alpha: (0.5, 0.8)
# Strength: 0.91
# 255.0 62.0
# Created corrupted image 290, alpha: (0.8, 1.0)
# Strength: 0.23
# 255.0 2.0
# Created corrupted image 291, alpha: (0.1, 0.5)
# Strength: 0.79
# 255.0 2.0
# Created corrupted image 291, alpha: (0.5, 0.8)
# Strength: 0.93
# 255.0 2.0
# Created corrupted image 291, alpha: (0.8, 1.0)
# Strength: 0.14
# 255.0 130.0
# Created corrupted image 292, alpha: (0.1, 0.5)
# Strength: 0.65
# 255.0 130.0
# Created corrupted image 292, alpha: (0.5, 0.8)
# Strength: 0.96
# 255.0 130.0
# Created corrupted image 292, alpha: (0.8, 1.0)
# Strength: 0.27
# 247.0 20.0
# Created corrupted image 293, alpha: (0.1, 0.5)
# Strength: 0.67
# 247.0 20.0
# Created corrupted image 293, alpha: (0.5, 0.8)
# Strength: 0.91
# 247.0 20.0
# Created corrupted image 293, alpha: (0.8, 1.0)
# Strength: 0.27
# 220.0 191.0
# Created corrupted image 294, alpha: (0.1, 0.5)
# Strength: 0.75
# 220.0 191.0
# Created corrupted image 294, alpha: (0.5, 0.8)
# Strength: 0.88
# 220.0 191.0
# Created corrupted image 294, alpha: (0.8, 1.0)
# Strength: 0.19
# 178.0 60.0
# Created corrupted image 295, alpha: (0.1, 0.5)
# Strength: 0.69
# 178.0 60.0
# Created corrupted image 295, alpha: (0.5, 0.8)
# Strength: 0.97
# 178.0 60.0
# Created corrupted image 295, alpha: (0.8, 1.0)
# Strength: 0.12
# 255.0 0.0
# Created corrupted image 296, alpha: (0.1, 0.5)
# Strength: 0.55
# 255.0 0.0
# Created corrupted image 296, alpha: (0.5, 0.8)
# Strength: 0.8
# 255.0 0.0
# Created corrupted image 296, alpha: (0.8, 1.0)
# Strength: 0.34
# 120.0 13.0
# Created corrupted image 297, alpha: (0.1, 0.5)
# Strength: 0.75
# 120.0 13.0
# Created corrupted image 297, alpha: (0.5, 0.8)
# Strength: 0.96
# 120.0 13.0
# Created corrupted image 297, alpha: (0.8, 1.0)
# Strength: 0.24
# 211.0 10.0
# Created corrupted image 298, alpha: (0.1, 0.5)
# Strength: 0.51
# 211.0 10.0
# Created corrupted image 298, alpha: (0.5, 0.8)
# Strength: 0.94
# 211.0 10.0
# Created corrupted image 298, alpha: (0.8, 1.0)
# Strength: 0.5
# 239.0 61.0
# Created corrupted image 299, alpha: (0.1, 0.5)
# Strength: 0.7
# 239.0 61.0
# Created corrupted image 299, alpha: (0.5, 0.8)
# Strength: 0.91
# 239.0 61.0
# Created corrupted image 299, alpha: (0.8, 1.0)
# Strength: 0.35
# 220.0 0.0
# Created corrupted image 300, alpha: (0.1, 0.5)
# Strength: 0.72
# 220.0 0.0
# Created corrupted image 300, alpha: (0.5, 0.8)
# Strength: 0.92
# 220.0 0.0
# Created corrupted image 300, alpha: (0.8, 1.0)
# Strength: 0.27
# 255.0 0.0
# Created corrupted image 301, alpha: (0.1, 0.5)
# Strength: 0.67
# 255.0 0.0
# Created corrupted image 301, alpha: (0.5, 0.8)
# Strength: 0.98
# 255.0 0.0
# Created corrupted image 301, alpha: (0.8, 1.0)
# Strength: 0.22
# 180.0 65.0
# Created corrupted image 302, alpha: (0.1, 0.5)
# Strength: 0.52
# 180.0 65.0
# Created corrupted image 302, alpha: (0.5, 0.8)
# Strength: 0.95
# 180.0 65.0
# Created corrupted image 302, alpha: (0.8, 1.0)
# Strength: 0.49
# 205.0 0.0
# Created corrupted image 303, alpha: (0.1, 0.5)
# Strength: 0.7
# 205.0 0.0
# Created corrupted image 303, alpha: (0.5, 0.8)
# Strength: 0.85
# 205.0 0.0
# Created corrupted image 303, alpha: (0.8, 1.0)
# Strength: 0.22
# 255.0 0.0
# Created corrupted image 304, alpha: (0.1, 0.5)
# Strength: 0.75
# 255.0 0.0
# Created corrupted image 304, alpha: (0.5, 0.8)
# Strength: 0.8
# 255.0 0.0
# Created corrupted image 304, alpha: (0.8, 1.0)
# Strength: 0.42
# 255.0 25.0
# Created corrupted image 305, alpha: (0.1, 0.5)
# Strength: 0.76
# 255.0 25.0
# Created corrupted image 305, alpha: (0.5, 0.8)
# Strength: 0.93
# 255.0 25.0
# Created corrupted image 305, alpha: (0.8, 1.0)
# Strength: 0.5
# 253.0 0.0
# Created corrupted image 306, alpha: (0.1, 0.5)
# Strength: 0.79
# 253.0 0.0
# Created corrupted image 306, alpha: (0.5, 0.8)
# Strength: 0.92
# 253.0 0.0
# Created corrupted image 306, alpha: (0.8, 1.0)
# Strength: 0.21
# 216.0 124.0
# Created corrupted image 307, alpha: (0.1, 0.5)
# Strength: 0.53
# 216.0 124.0
# Created corrupted image 307, alpha: (0.5, 0.8)
# Strength: 0.98
# 216.0 124.0
# Created corrupted image 307, alpha: (0.8, 1.0)
# Strength: 0.22
# 255.0 0.0
# Created corrupted image 308, alpha: (0.1, 0.5)
# Strength: 0.61
# 255.0 0.0
# Created corrupted image 308, alpha: (0.5, 0.8)
# Strength: 0.94
# 255.0 0.0
# Created corrupted image 308, alpha: (0.8, 1.0)
# Strength: 0.27
# 204.0 2.0
# Created corrupted image 309, alpha: (0.1, 0.5)
# Strength: 0.66
# 204.0 2.0
# Created corrupted image 309, alpha: (0.5, 0.8)
# Strength: 0.98
# 204.0 2.0
# Created corrupted image 309, alpha: (0.8, 1.0)
# Strength: 0.37
# 255.0 7.0
# Created corrupted image 310, alpha: (0.1, 0.5)
# Strength: 0.59
# 255.0 7.0
# Created corrupted image 310, alpha: (0.5, 0.8)
# Strength: 0.84
# 255.0 7.0
# Created corrupted image 310, alpha: (0.8, 1.0)
# Strength: 0.18
# 248.0 0.0
# Created corrupted image 311, alpha: (0.1, 0.5)
# Strength: 0.52
# 248.0 0.0
# Created corrupted image 311, alpha: (0.5, 0.8)
# Strength: 0.81
# 248.0 0.0
# Created corrupted image 311, alpha: (0.8, 1.0)
# Strength: 0.14
# 161.0 8.0
# Created corrupted image 312, alpha: (0.1, 0.5)
# Strength: 0.58
# 161.0 8.0
# Created corrupted image 312, alpha: (0.5, 0.8)
# Strength: 0.84
# 161.0 8.0
# Created corrupted image 312, alpha: (0.8, 1.0)
# Strength: 0.4
# 249.0 0.0
# Created corrupted image 313, alpha: (0.1, 0.5)
# Strength: 0.6
# 249.0 0.0
# Created corrupted image 313, alpha: (0.5, 0.8)
# Strength: 0.87
# 249.0 0.0
# Created corrupted image 313, alpha: (0.8, 1.0)
# Strength: 0.22
# 252.0 0.0
# Created corrupted image 314, alpha: (0.1, 0.5)
# Strength: 0.6
# 252.0 0.0
# Created corrupted image 314, alpha: (0.5, 0.8)
# Strength: 0.89
# 252.0 0.0
# Created corrupted image 314, alpha: (0.8, 1.0)
# Strength: 0.15
# 255.0 0.0
# Created corrupted image 315, alpha: (0.1, 0.5)
# Strength: 0.56
# 255.0 0.0
# Created corrupted image 315, alpha: (0.5, 0.8)
# Strength: 0.97
# 255.0 0.0
# ...
# Strength: 0.97
# 255.0 1.0
# Created corrupted image 576, alpha: (0.8, 1.0)
# Strength: 0.36
# 211.0 119.0
# Created corrupted image 577, alpha: (0.1, 0.5)
# Strength: 0.76
# 211.0 119.0
# Created corrupted image 577, alpha: (0.5, 0.8)
# Strength: 0.97
# 211.0 119.0
# Created corrupted image 577, alpha: (0.8, 1.0)
# Strength: 0.29
# 255.0 20.0
# Created corrupted image 578, alpha: (0.1, 0.5)
# Strength: 0.67
# 255.0 20.0
# Created corrupted image 578, alpha: (0.5, 0.8)
# Strength: 0.91
# 255.0 20.0
# Created corrupted image 578, alpha: (0.8, 1.0)
# Strength: 0.49
# 255.0 128.0
# Created corrupted image 579, alpha: (0.1, 0.5)
# Strength: 0.69
# 255.0 128.0
# Created corrupted image 579, alpha: (0.5, 0.8)
# Strength: 0.94
# 255.0 128.0
# Created corrupted image 579, alpha: (0.8, 1.0)
# Strength: 0.42
# 255.0 0.0
# Created corrupted image 580, alpha: (0.1, 0.5)
# Strength: 0.7
# 255.0 0.0
# Created corrupted image 580, alpha: (0.5, 0.8)
# Strength: 0.88
# 255.0 0.0
# Created corrupted image 580, alpha: (0.8, 1.0)
# Strength: 0.37
# 255.0 2.0
# Created corrupted image 581, alpha: (0.1, 0.5)
# Strength: 0.61
# 255.0 2.0
# Created corrupted image 581, alpha: (0.5, 0.8)
# Strength: 0.98
# 255.0 2.0
# Created corrupted image 581, alpha: (0.8, 1.0)
# Strength: 0.17
# 255.0 0.0
# Created corrupted image 582, alpha: (0.1, 0.5)
# Strength: 0.6
# 255.0 0.0
# Created corrupted image 582, alpha: (0.5, 0.8)
# Strength: 0.93
# 255.0 0.0
# Created corrupted image 582, alpha: (0.8, 1.0)
# Strength: 0.37
# 255.0 0.0
# Created corrupted image 583, alpha: (0.1, 0.5)
# Strength: 0.71
# 255.0 0.0
# Created corrupted image 583, alpha: (0.5, 0.8)
# Strength: 0.93
# 255.0 0.0
# Created corrupted image 583, alpha: (0.8, 1.0)
# Strength: 0.45
# 255.0 0.0
# Created corrupted image 584, alpha: (0.1, 0.5)
# Strength: 0.72
# 255.0 0.0
# Created corrupted image 584, alpha: (0.5, 0.8)
# Strength: 0.93
# 255.0 0.0
# Created corrupted image 584, alpha: (0.8, 1.0)
# Strength: 0.11
# 255.0 19.0
# Created corrupted image 585, alpha: (0.1, 0.5)
# Strength: 0.79
# 255.0 19.0
# Created corrupted image 585, alpha: (0.5, 0.8)
# Strength: 0.94
# 255.0 19.0
# Created corrupted image 585, alpha: (0.8, 1.0)
# Strength: 0.14
# 249.0 12.0
# Created corrupted image 586, alpha: (0.1, 0.5)
# Strength: 0.52
# 249.0 12.0
# Created corrupted image 586, alpha: (0.5, 0.8)
# Strength: 0.81
# 249.0 12.0
# Created corrupted image 586, alpha: (0.8, 1.0)
# Strength: 0.16
# 255.0 0.0
# Created corrupted image 587, alpha: (0.1, 0.5)
# Strength: 0.51
# 255.0 0.0
# Created corrupted image 587, alpha: (0.5, 0.8)
# Strength: 0.86
# 255.0 0.0
# Created corrupted image 587, alpha: (0.8, 1.0)
# Strength: 0.39
# 255.0 0.0
# Created corrupted image 588, alpha: (0.1, 0.5)
# Strength: 0.77
# 255.0 0.0
# Created corrupted image 588, alpha: (0.5, 0.8)
# Strength: 0.94
# 255.0 0.0
# Created corrupted image 588, alpha: (0.8, 1.0)
# Strength: 0.15
# 232.0 0.0
# Created corrupted image 589, alpha: (0.1, 0.5)
# Strength: 0.79
# 232.0 0.0
# Created corrupted image 589, alpha: (0.5, 0.8)
# Strength: 0.9
# 232.0 0.0
# Created corrupted image 589, alpha: (0.8, 1.0)
# Strength: 0.41
# 255.0 0.0
# Created corrupted image 590, alpha: (0.1, 0.5)
# Strength: 0.53
# 255.0 0.0
# Created corrupted image 590, alpha: (0.5, 0.8)
# Strength: 0.99
# 255.0 0.0
# Created corrupted image 590, alpha: (0.8, 1.0)
# Strength: 0.46
# 181.0 0.0
# Created corrupted image 591, alpha: (0.1, 0.5)
# Strength: 0.71
# 181.0 0.0
# Created corrupted image 591, alpha: (0.5, 0.8)
# Strength: 0.85
# 181.0 0.0
# Created corrupted image 591, alpha: (0.8, 1.0)
# Strength: 0.13
# 210.0 7.0
# Created corrupted image 592, alpha: (0.1, 0.5)
# Strength: 0.64
# 210.0 7.0
# Created corrupted image 592, alpha: (0.5, 0.8)
# Strength: 0.82
# 210.0 7.0
# Created corrupted image 592, alpha: (0.8, 1.0)
# Strength: 0.46
# 179.0 25.0
# Created corrupted image 593, alpha: (0.1, 0.5)
# Strength: 0.77
# 179.0 25.0
# Created corrupted image 593, alpha: (0.5, 0.8)
# Strength: 0.81
# 179.0 25.0
# Created corrupted image 593, alpha: (0.8, 1.0)
# Strength: 0.16
# 255.0 0.0
# Created corrupted image 594, alpha: (0.1, 0.5)
# Strength: 0.58
# 255.0 0.0
# Created corrupted image 594, alpha: (0.5, 0.8)
# Strength: 0.92
# 255.0 0.0
# Created corrupted image 594, alpha: (0.8, 1.0)
# Strength: 0.45
# 182.0 0.0
# Created corrupted image 595, alpha: (0.1, 0.5)
# Strength: 0.54
# 182.0 0.0
# Created corrupted image 595, alpha: (0.5, 0.8)
# Strength: 0.8
# 182.0 0.0
# Created corrupted image 595, alpha: (0.8, 1.0)
# Strength: 0.32
# 255.0 54.0
# Created corrupted image 596, alpha: (0.1, 0.5)
# Strength: 0.53
# 255.0 54.0
# Created corrupted image 596, alpha: (0.5, 0.8)
# Strength: 1.0
# 255.0 54.0
# Created corrupted image 596, alpha: (0.8, 1.0)
# Strength: 0.47
# 243.0 2.0
# Created corrupted image 597, alpha: (0.1, 0.5)
# Strength: 0.67
# 243.0 2.0
# Created corrupted image 597, alpha: (0.5, 0.8)
# Strength: 0.85
# 243.0 2.0
# Created corrupted image 597, alpha: (0.8, 1.0)
# Strength: 0.15
# 255.0 0.0
# Created corrupted image 598, alpha: (0.1, 0.5)
# Strength: 0.51
# 255.0 0.0
# Created corrupted image 598, alpha: (0.5, 0.8)
# Strength: 0.86
# 255.0 0.0
# Created corrupted image 598, alpha: (0.8, 1.0)
# Strength: 0.19
# 250.0 0.0
# Created corrupted image 599, alpha: (0.1, 0.5)
# Strength: 0.5
# 250.0 0.0
# Created corrupted image 599, alpha: (0.5, 0.8)
# Strength: 0.85
# 250.0 0.0
# Created corrupted image 599, alpha: (0.8, 1.0)
# Strength: 0.49
# 186.0 54.0
# Created corrupted image 600, alpha: (0.1, 0.5)
# Strength: 0.59
# 186.0 54.0
# Created corrupted image 600, alpha: (0.5, 0.8)
# Strength: 0.98
# 186.0 54.0
# Created corrupted image 600, alpha: (0.8, 1.0)
# Strength: 0.35
# 255.0 28.0
# Created corrupted image 601, alpha: (0.1, 0.5)
# Strength: 0.78
# 255.0 28.0
# Created corrupted image 601, alpha: (0.5, 0.8)
# Strength: 0.96
# 255.0 28.0
# Created corrupted image 601, alpha: (0.8, 1.0)
# Strength: 0.27
# 255.0 0.0
# Created corrupted image 602, alpha: (0.1, 0.5)
# Strength: 0.79
# 255.0 0.0
# Created corrupted image 602, alpha: (0.5, 0.8)
# Strength: 0.84
# 255.0 0.0
# Created corrupted image 602, alpha: (0.8, 1.0)
# Strength: 0.17
# 255.0 0.0
# Created corrupted image 603, alpha: (0.1, 0.5)
# Strength: 0.62
# 255.0 0.0
# Created corrupted image 603, alpha: (0.5, 0.8)
# Strength: 0.91
# 255.0 0.0
# Created corrupted image 603, alpha: (0.8, 1.0)
# Strength: 0.19
# 255.0 0.0
# Created corrupted image 604, alpha: (0.1, 0.5)
# Strength: 0.68
# 255.0 0.0
# Created corrupted image 604, alpha: (0.5, 0.8)
# Strength: 0.85
# 255.0 0.0
# Created corrupted image 604, alpha: (0.8, 1.0)
# Strength: 0.37
# 255.0 0.0
# Created corrupted image 605, alpha: (0.1, 0.5)
# Strength: 0.52
# 255.0 0.0
# Created corrupted image 605, alpha: (0.5, 0.8)
# Strength: 0.89
# 255.0 0.0
# Created corrupted image 605, alpha: (0.8, 1.0)
# Strength: 0.16
# 255.0 0.0
# Created corrupted image 606, alpha: (0.1, 0.5)
# Strength: 0.54
# 255.0 0.0
# Created corrupted image 606, alpha: (0.5, 0.8)
# Strength: 0.82
# 255.0 0.0
# Created corrupted image 606, alpha: (0.8, 1.0)
# Strength: 0.14
# 254.0 38.0
# Created corrupted image 607, alpha: (0.1, 0.5)
# Strength: 0.56
# 254.0 38.0
# Created corrupted image 607, alpha: (0.5, 0.8)
# Strength: 0.99
# 254.0 38.0
# Created corrupted image 607, alpha: (0.8, 1.0)
# Strength: 0.4
# 198.0 0.0
# Created corrupted image 608, alpha: (0.1, 0.5)
# Strength: 0.54
# 198.0 0.0
# Created corrupted image 608, alpha: (0.5, 0.8)
# Strength: 0.93
# 198.0 0.0
# Created corrupted image 608, alpha: (0.8, 1.0)
# Strength: 0.42
# 255.0 0.0
# Created corrupted image 609, alpha: (0.1, 0.5)
# Strength: 0.56
# 255.0 0.0
# Created corrupted image 609, alpha: (0.5, 0.8)
# Strength: 0.9
# 255.0 0.0
# Created corrupted image 609, alpha: (0.8, 1.0)
# Strength: 0.15
# 202.0 4.0
# Created corrupted image 610, alpha: (0.1, 0.5)
# Strength: 0.76
# 202.0 4.0
# Created corrupted image 610, alpha: (0.5, 0.8)
# Strength: 0.96
# 202.0 4.0
# Created corrupted image 610, alpha: (0.8, 1.0)
# Strength: 0.29
# 255.0 11.0
# Created corrupted image 611, alpha: (0.1, 0.5)
# Strength: 0.65
# 255.0 11.0
# Created corrupted image 611, alpha: (0.5, 0.8)
# Strength: 0.88
# 255.0 11.0
# Created corrupted image 611, alpha: (0.8, 1.0)
# Strength: 0.1
# 224.0 0.0
# Created corrupted image 612, alpha: (0.1, 0.5)
# Strength: 0.64
# 224.0 0.0
# Created corrupted image 612, alpha: (0.5, 0.8)
# Strength: 0.93
# 224.0 0.0
# Created corrupted image 612, alpha: (0.8, 1.0)
# Strength: 0.21
# 255.0 6.0
# Created corrupted image 613, alpha: (0.1, 0.5)
# Strength: 0.64
# 255.0 6.0
# Created corrupted image 613, alpha: (0.5, 0.8)
# Strength: 0.84
# 255.0 6.0
# Created corrupted image 613, alpha: (0.8, 1.0)
# Strength: 0.31
# 255.0 0.0
# Created corrupted image 614, alpha: (0.1, 0.5)
# Strength: 0.76
# 255.0 0.0
# Created corrupted image 614, alpha: (0.5, 0.8)
# Strength: 0.93
# 255.0 0.0
# Created corrupted image 614, alpha: (0.8, 1.0)
# Strength: 0.19
# 255.0 0.0
# Created corrupted image 615, alpha: (0.1, 0.5)
# Strength: 0.61
# 255.0 0.0
# Created corrupted image 615, alpha: (0.5, 0.8)
# Strength: 0.8
# 255.0 0.0
# Created corrupted image 615, alpha: (0.8, 1.0)
# Strength: 0.4
# 243.0 0.0
# Created corrupted image 616, alpha: (0.1, 0.5)
# Strength: 0.55
# 243.0 0.0
# Created corrupted image 616, alpha: (0.5, 0.8)
# Strength: 0.96
# 243.0 0.0
# Created corrupted image 616, alpha: (0.8, 1.0)
# Strength: 0.16
# 255.0 130.0
# Created corrupted image 617, alpha: (0.1, 0.5)
# Strength: 0.68
# 255.0 130.0
# Created corrupted image 617, alpha: (0.5, 0.8)
# Strength: 0.94
# 255.0 130.0
# Created corrupted image 617, alpha: (0.8, 1.0)
# Strength: 0.13
# 255.0 31.0
# Created corrupted image 618, alpha: (0.1, 0.5)
# Strength: 0.63
# 255.0 31.0
# Created corrupted image 618, alpha: (0.5, 0.8)
# Strength: 0.8
# 255.0 31.0
# Created corrupted image 618, alpha: (0.8, 1.0)
# Strength: 0.34
# 255.0 0.0
# Created corrupted image 619, alpha: (0.1, 0.5)
# Strength: 0.5
# 255.0 0.0
# Created corrupted image 619, alpha: (0.5, 0.8)
# Strength: 0.9
# 255.0 0.0
# Created corrupted image 619, alpha: (0.8, 1.0)
# Strength: 0.24
# 251.0 2.0
# Created corrupted image 620, alpha: (0.1, 0.5)
# Strength: 0.8
# 251.0 2.0
# Created corrupted image 620, alpha: (0.5, 0.8)
# Strength: 0.86
# 251.0 2.0
# Created corrupted image 620, alpha: (0.8, 1.0)
# Strength: 0.3
# 255.0 0.0
# Created corrupted image 621, alpha: (0.1, 0.5)
# Strength: 0.52
# 255.0 0.0
# Created corrupted image 621, alpha: (0.5, 0.8)
# Strength: 0.99
# 255.0 0.0
# Created corrupted image 621, alpha: (0.8, 1.0)
# Strength: 0.41
# 218.0 0.0
# Created corrupted image 622, alpha: (0.1, 0.5)
# Strength: 0.74
# 218.0 0.0
# Created corrupted image 622, alpha: (0.5, 0.8)
# Strength: 0.96
# 218.0 0.0
# Created corrupted image 622, alpha: (0.8, 1.0)
# Strength: 0.44
# 255.0 0.0
# Created corrupted image 623, alpha: (0.1, 0.5)
# Strength: 0.57
# 255.0 0.0
# Created corrupted image 623, alpha: (0.5, 0.8)
# Strength: 0.87
# 255.0 0.0
# Created corrupted image 623, alpha: (0.8, 1.0)
# Strength: 0.32
# 255.0 0.0
# Created corrupted image 624, alpha: (0.1, 0.5)
# Strength: 0.66
# 255.0 0.0
# Created corrupted image 624, alpha: (0.5, 0.8)
# Strength: 0.8
# 255.0 0.0
# Created corrupted image 624, alpha: (0.8, 1.0)
# Strength: 0.42
# 255.0 35.0
# Created corrupted image 625, alpha: (0.1, 0.5)
# Strength: 0.69
# 255.0 35.0
# Created corrupted image 625, alpha: (0.5, 0.8)
# Strength: 0.89
# 255.0 35.0
# Created corrupted image 625, alpha: (0.8, 1.0)
# Strength: 0.15
# 255.0 7.0
# Created corrupted image 626, alpha: (0.1, 0.5)
# Strength: 0.61
# 255.0 7.0
# Created corrupted image 626, alpha: (0.5, 0.8)
# Strength: 0.96
# 255.0 7.0
# Created corrupted image 626, alpha: (0.8, 1.0)
# Strength: 0.47
# 199.0 0.0
# Created corrupted image 627, alpha: (0.1, 0.5)
# Strength: 0.74
# 199.0 0.0
# Created corrupted image 627, alpha: (0.5, 0.8)
# Strength: 0.82
# 199.0 0.0
# Created corrupted image 627, alpha: (0.8, 1.0)
# Strength: 0.39
# 255.0 47.0
# Created corrupted image 628, alpha: (0.1, 0.5)
# Strength: 0.76
# 255.0 47.0
# Created corrupted image 628, alpha: (0.5, 0.8)
# Strength: 0.86
# 255.0 47.0
# Created corrupted image 628, alpha: (0.8, 1.0)
# Strength: 0.37
# 210.0 7.0
# Created corrupted image 629, alpha: (0.1, 0.5)
# Strength: 0.55
# 210.0 7.0
# Created corrupted image 629, alpha: (0.5, 0.8)
# Strength: 0.96
# 210.0 7.0
# Created corrupted image 629, alpha: (0.8, 1.0)
# Strength: 0.14
# 255.0 0.0
# Created corrupted image 630, alpha: (0.1, 0.5)
# Strength: 0.52
# 255.0 0.0
# Created corrupted image 630, alpha: (0.5, 0.8)
# Strength: 0.88
# 255.0 0.0
# Created corrupted image 630, alpha: (0.8, 1.0)
# Strength: 0.31
# 255.0 0.0
# Created corrupted image 631, alpha: (0.1, 0.5)
# Strength: 0.67
# 255.0 0.0
# Created corrupted image 631, alpha: (0.5, 0.8)
# Strength: 0.83
# 255.0 0.0
# Created corrupted image 631, alpha: (0.8, 1.0)
# Strength: 0.23
# 249.0 7.0
# Created corrupted image 632, alpha: (0.1, 0.5)
# Strength: 0.62
# 249.0 7.0
# Created corrupted image 632, alpha: (0.5, 0.8)
# Strength: 0.91
# 249.0 7.0
# Created corrupted image 632, alpha: (0.8, 1.0)
# Strength: 0.22
# 255.0 0.0
# Created corrupted image 633, alpha: (0.1, 0.5)
# Strength: 0.73
# 255.0 0.0
# Created corrupted image 633, alpha: (0.5, 0.8)
# Strength: 0.82
# 255.0 0.0
# Created corrupted image 633, alpha: (0.8, 1.0)
# Strength: 0.38
# 255.0 0.0
# Created corrupted image 634, alpha: (0.1, 0.5)
# Strength: 0.73
# 255.0 0.0
# Created corrupted image 634, alpha: (0.5, 0.8)
# Strength: 0.87
# 255.0 0.0
# Created corrupted image 634, alpha: (0.8, 1.0)
# Strength: 0.42
# 205.0 34.0
# Created corrupted image 635, alpha: (0.1, 0.5)
# Strength: 0.52
# 205.0 34.0
# Created corrupted image 635, alpha: (0.5, 0.8)
# Strength: 0.98
# 205.0 34.0
# Created corrupted image 635, alpha: (0.8, 1.0)
# Strength: 0.48
# 255.0 0.0
# Created corrupted image 636, alpha: (0.1, 0.5)
# Strength: 0.75
# 255.0 0.0
# Created corrupted image 636, alpha: (0.5, 0.8)
# Strength: 0.82
# 255.0 0.0
# Created corrupted image 636, alpha: (0.8, 1.0)
# Strength: 0.31
# 255.0 0.0
# Created corrupted image 637, alpha: (0.1, 0.5)
# Strength: 0.53
# 255.0 0.0
# Created corrupted image 637, alpha: (0.5, 0.8)
# Strength: 0.93
# 255.0 0.0
# Created corrupted image 637, alpha: (0.8, 1.0)
# Strength: 0.35
# 255.0 5.0
# Created corrupted image 638, alpha: (0.1, 0.5)
# Strength: 0.75
# 255.0 5.0
# Created corrupted image 638, alpha: (0.5, 0.8)
# Strength: 0.91
# 255.0 5.0
# Created corrupted image 638, alpha: (0.8, 1.0)
# Strength: 0.45
# 229.0 76.0
# Created corrupted image 639, alpha: (0.1, 0.5)
# Strength: 0.67
# 229.0 76.0
# Created corrupted image 639, alpha: (0.5, 0.8)
# Strength: 1.0
# 229.0 76.0
# Created corrupted image 639, alpha: (0.8, 1.0)
# Strength: 0.48
# 226.0 0.0
# Created corrupted image 640, alpha: (0.1, 0.5)
# Strength: 0.75
# 226.0 0.0
# Created corrupted image 640, alpha: (0.5, 0.8)
# Strength: 0.91
# 226.0 0.0
# Created corrupted image 640, alpha: (0.8, 1.0)
# Strength: 0.22
# 255.0 0.0
# Created corrupted image 641, alpha: (0.1, 0.5)
# Strength: 0.64
# 255.0 0.0
# Created corrupted image 641, alpha: (0.5, 0.8)
# Strength: 0.84
# 255.0 0.0
# Created corrupted image 641, alpha: (0.8, 1.0)
# Strength: 0.35
# 255.0 9.0
# Created corrupted image 642, alpha: (0.1, 0.5)
# Strength: 0.78
# 255.0 9.0
# Created corrupted image 642, alpha: (0.5, 0.8)
# Strength: 0.96
# 255.0 9.0
# Created corrupted image 642, alpha: (0.8, 1.0)
# Strength: 0.22
# 228.0 0.0
# Created corrupted image 643, alpha: (0.1, 0.5)
# Strength: 0.54
# 228.0 0.0
# Created corrupted image 643, alpha: (0.5, 0.8)
# Strength: 0.94
# 228.0 0.0
# Created corrupted image 643, alpha: (0.8, 1.0)
# Strength: 0.17
# 164.0 9.0
# Created corrupted image 644, alpha: (0.1, 0.5)
# Strength: 0.76
# 164.0 9.0
# Created corrupted image 644, alpha: (0.5, 0.8)
# Strength: 0.86
# 164.0 9.0
# Created corrupted image 644, alpha: (0.8, 1.0)
# Strength: 0.24
# 245.0 13.0
# Created corrupted image 645, alpha: (0.1, 0.5)
# Strength: 0.76
# 245.0 13.0
# Created corrupted image 645, alpha: (0.5, 0.8)
# Strength: 0.83
# 245.0 13.0
# Created corrupted image 645, alpha: (0.8, 1.0)
# Strength: 0.15
# 255.0 0.0
# Created corrupted image 646, alpha: (0.1, 0.5)
# Strength: 0.71
# 255.0 0.0
# Created corrupted image 646, alpha: (0.5, 0.8)
# Strength: 0.91
# 255.0 0.0
# Created corrupted image 646, alpha: (0.8, 1.0)
# Strength: 0.19
# 230.0 0.0
# Created corrupted image 647, alpha: (0.1, 0.5)
# Strength: 0.56
# 230.0 0.0
# Created corrupted image 647, alpha: (0.5, 0.8)
# Strength: 0.95
# 230.0 0.0
# Created corrupted image 647, alpha: (0.8, 1.0)
# Strength: 0.11
# 147.0 0.0
# Created corrupted image 648, alpha: (0.1, 0.5)
# Strength: 0.53
# 147.0 0.0
# Created corrupted image 648, alpha: (0.5, 0.8)
# Strength: 0.91
# 147.0 0.0
# Created corrupted image 648, alpha: (0.8, 1.0)
# Strength: 0.34
# 255.0 0.0
# Created corrupted image 649, alpha: (0.1, 0.5)
# Strength: 0.7
# 255.0 0.0
# Created corrupted image 649, alpha: (0.5, 0.8)
# Strength: 0.95
# 255.0 0.0
# Created corrupted image 649, alpha: (0.8, 1.0)
# Metadata saved to /content/drive/MyDrive/Chris/data/train_dataset/metadata.json
# ✓ All files saved to Google Drive!

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import shutil

# Source directory
source_dir = '/content/drive/MyDrive/Chris/data/train_dataset/corrupted'

# Target directories
target_dirs = {
    'alpha01-05': '/content/drive/MyDrive/Chris/data/eval_dataset/alpha01-05',
    'alpha05-08': '/content/drive/MyDrive/Chris/data/eval_dataset/alpha05-08',
    'alpha08-10': '/content/drive/MyDrive/Chris/data/eval_dataset/alpha08-10'
}

# Create target directories
for dir_path in target_dirs.values():
    os.makedirs(dir_path, exist_ok=True)

# Split files based on naming pattern
for filename in os.listdir(source_dir):
    if filename.endswith('.png'):
        source_path = os.path.join(source_dir, filename)

        if 'alpha01-05' in filename:
            shutil.copy2(source_path, target_dirs['alpha01-05'])
        elif 'alpha05-08' in filename:
            shutil.copy2(source_path, target_dirs['alpha05-08'])
        elif 'alpha08-10' in filename:
            shutil.copy2(source_path, target_dirs['alpha08-10'])

print("Files split successfully!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Files split successfully!
